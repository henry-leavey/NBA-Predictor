# %% [markdown]
# # Modelling Preprocessing
#
# This is the preprocessing applied in production.
# - Train/test split
# - Scaling (StandardScaler, MinMaxScaler, RobustScaler)
# - Normalisation (L2 norm)
# - Full imputation
# - Outlier handling
# - Pipeline creation (sklearn Pipelines, SageMaker Pipelines)

# %% [markdown]
# Scaling all the column values for training, making sure to remove values which are invalid for scaling

# %%
import pandas as pd

df = pd.read_pickle('df_nba_games.pkl')

# %%
df.head()
# Out:
#       mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0  240.0  36.0  79.0  0.456   6.0  18.0  0.333  24.0  27.0  0.889  ...
# 1  240.0  38.0  76.0  0.500   8.0  23.0  0.348  15.0  24.0  0.625  ...
# 2  240.0  32.0  84.0  0.381   9.0  23.0  0.391  16.0  21.0  0.762  ...
# 3  240.0  35.0  90.0  0.389   4.0  16.0  0.250  17.0  18.0  0.944  ...
# 4  240.0  33.0  79.0  0.418  12.0  32.0  0.375  16.0  22.0  0.727  ...
#
#    usg%_max_opp_10_y  ortg_max_opp_10_y  drtg_max_opp_10_y  total_opp_10_y  \
# 0               25.3              150.0              102.0           107.0
# 1               28.1              130.0              116.0            96.0
# 2               46.6              180.0              110.0            97.0
# 3               45.2              127.0              112.0           102.0
# 4               27.8              176.0              110.0           108.0
#
#    home_opp_10_y  won_10_y  season_10_y  team_opp_next_y  team_y  days_rested
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

removed_columns = ["season", "season_10_x" "date", "won", "target", "team", "team_opp", "team_x", "team_y"]
selected_columns = df.columns[~df.columns.isin(removed_columns)]

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10148/2313037259.py in <module>
#       5
#       6 scaler = MinMaxScaler()
# ----> 7 df[selected_columns] = scaler.fit_transform(df[selected_columns])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
# ...

# %%
df.head()

# %%
df.to_pickle('df_nba_games_processed.pkl')
