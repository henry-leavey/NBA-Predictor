# %% [markdown]
# # Modelling Preprocessing
#
# This is the preprocessing applied in production.
# - Train/test split
# - Scaling (StandardScaler, MinMaxScaler, RobustScaler)
# - Normalisation (L2 norm)
# - Full imputation
# - Outlier handling
# - Pipeline creation (sklearn Pipelines, SageMaker Pipelines)

# %% [markdown]
# Scaling all the column values for training, making sure to remove values which are invalid for scaling

# %%
import pandas as pd

df = pd.read_pickle('df_nba_games.pkl')

# %%
df.head()
# Out:
#       season       date team team_opp  mp_10  fg_10  fga_10  fg%_10  3p_10  \
# 2696    2017 2016-10-29  IND      CHI  252.5   42.0    95.5  0.4415    8.5
# 2681    2017 2016-10-29  NOP      SAS  240.0   42.5    96.0  0.4415    4.0
# 2692    2017 2016-10-29  ORL      CLE  240.0   33.5    92.0  0.3645    7.0
# 2709    2017 2016-10-30  DAL      HOU  252.5   40.0    92.0  0.4355   13.0
# 2702    2017 2016-10-30  LAL      OKC  240.0   38.5    86.5  0.4435   10.5
#
#       3pa_10  ...  tov%_max_opp_10  usg%_max_opp_10  ortg_max_opp_10  \
# 2696    21.5  ...            25.00            33.75            189.5
# 2681    20.5  ...            34.70            27.50            225.0
# 2692    22.0  ...            58.05            31.65            188.0
# 2709    38.5  ...            31.25            38.20            167.5
# 2702    29.0  ...            65.00            37.95            176.5
#
#       drtg_max_opp_10  total_opp_10  home_opp_10  won_10  days_rested  \
# ...

# %%
df.describe()
# Out:
#             season        mp_10        fg_10       fga_10       fg%_10  \
# count  7466.000000  7466.000000  7466.000000  7466.000000  7466.000000
# mean   2017.998795   241.550202    39.851061    86.798273     0.460038
# std       0.816195     2.318255     2.434899     3.561456     0.022425
# min    2017.000000   240.000000    32.000000    73.000000     0.360500
# 25%    2017.000000   240.000000    38.200000    84.400000     0.444100
# 50%    2018.000000   240.000000    39.700000    86.800000     0.459200
# 75%    2019.000000   242.500000    41.500000    89.100000     0.474900
# max    2019.000000   252.500000    54.000000   100.333333     0.560000
#
#              3p_10       3pa_10       3p%_10        ft_10       fta_10  ...  \
# count  7466.000000  7466.000000  7466.000000  7466.000000  7466.000000  ...
# mean     10.497868    29.325775     0.357568    17.499598    22.762324  ...
# std       2.058405     5.121978     0.032882     2.667474     3.321188  ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

removed_columns = ["season", "date", "team", "team_opp", "won"]
selected_columns = df.columns[~df.columns.isin(removed_columns)]

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df['won'] = df['won'].astype(int)

# %%
df.head()
# Out:
#       season       date team team_opp  mp_10     fg_10    fga_10    fg%_10  \
# 2696    2017 2016-10-29  IND      CHI    1.0  0.454545  0.823171  0.406015
# 2681    2017 2016-10-29  NOP      SAS    0.0  0.477273  0.841463  0.406015
# 2692    2017 2016-10-29  ORL      CLE    0.0  0.068182  0.695122  0.020050
# 2709    2017 2016-10-30  DAL      HOU    1.0  0.363636  0.695122  0.375940
# 2702    2017 2016-10-30  LAL      OKC    0.0  0.295455  0.493902  0.416040
#
#          3p_10    3pa_10  ...  tov%_max_opp_10  usg%_max_opp_10  \
# 2696  0.308642  0.145349  ...         0.083130         0.295201
# 2681  0.030864  0.116279  ...         0.201711         0.027421
# 2692  0.216049  0.159884  ...         0.487164         0.205227
# 2709  0.586420  0.639535  ...         0.159535         0.485861
# 2702  0.432099  0.363372  ...         0.572127         0.475150
#
#       ortg_max_opp_10  drtg_max_opp_10  total_opp_10  home_opp_10  won_10  \
# ...

# %%
df.to_pickle('df_nba_games_processed.pkl')
