# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# %%
SCORE_DIR = "data/scores"

# %%
box_scores = os.listdir(SCORE_DIR)

# %%
box_scores = [os.path.join(SCORE_DIR, f) for f in box_scores if f.endswith(".html")]

# %%
def parse_html(box_score):
    html = None
    # Try UTF-8 first
    try:
        with open(box_score, 'r', encoding="utf-8") as f:
            html = f.read()
    except UnicodeDecodeError:
        # Try cp1252 (Windows-1252) if UTF-8 fails
        try:
            with open(box_score, 'r', encoding="cp1252") as f:
                html = f.read()
        except UnicodeDecodeError:
            print(f"⚠️ Skipping file due to encoding error: {box_score}")
            return None

    if not html or html.strip() == "":
        print(f"⚠️ Skipping empty file: {box_score}")
        return None

    soup = BeautifulSoup(html, "html.parser")
    [s.decompose() for s in soup.select("tr.over_header")]
    [s.decompose() for s in soup.select("tr.thead")]
    return soup

# %%
def read_line_score(soup):
    try:
        line_score = pd.read_html(str(soup), attrs={"id": "line_score"})[0]
    except (ValueError, IndexError):
        # ValueError: no tables found, IndexError: empty result
        return None

    cols = list(line_score.columns)
    cols[0] = "team"
    cols[-1] = "total"
    line_score.columns = cols

    return line_score[["team", "total"]]

# %%
def read_stats(soup, team, stat):
    try:
        df = pd.read_html(
            str(soup), attrs={"id": f"box-{team}-game-{stat}"}, index_col=0
        )[0]
    except (ValueError, IndexError):
        return None

    return df.apply(pd.to_numeric, errors="coerce")

# %%
def read_season_info(soup):
    try:
        nav = soup.select("#bottom_nav_container")[0]
        hrefs = [a["href"] for a in nav.find_all("a")]
        season = os.path.basename(hrefs[1]).split("_")[0]
        return season
    except Exception:
        return None

# %%
base_cols = None
games = []

for box_score in box_scores:
    soup = parse_html(box_score)
    if soup is None:
        continue

    line_score = read_line_score(soup)
    if line_score is None:
        print(f"⚠️ Skipping file with no line_score: {box_score}")
        continue

    teams = list(line_score["team"])
    summaries = []

    for team in teams:
        basic = read_stats(soup, team, "basic")
        advanced = read_stats(soup, team, "advanced")
        if basic is None or advanced is None:
            print(f"⚠️ Skipping {box_score} due to missing stats for {team}")
            summaries = []
            break

        totals = pd.concat([basic.iloc[-1,:], advanced.iloc[-1,:]])
        totals.index = totals.index.str.lower()

        maxes = pd.concat([basic.iloc[:-1,:].max(), advanced.iloc[:-1,:].max()])
        maxes.index = maxes.index.str.lower() + "_max"

        summary = pd.concat([totals, maxes])

        if base_cols is None:
            base_cols = list(summary.index.drop_duplicates(keep="first"))
            base_cols = [b for b in base_cols if "bpm" not in b]

        summary = summary[base_cols]
        summaries.append(summary)

    if not summaries:
        continue  # skip incomplete game

    summary = pd.concat(summaries, axis=1).T
    game = pd.concat([summary, line_score], axis=1)

    game["home"] = [0, 1]
    game_opp = game.iloc[::-1].reset_index()
    game_opp.columns += "_opp"

    full_game = pd.concat([game, game_opp], axis=1)
    full_game["season"] = read_season_info(soup)
    full_game["date"] = pd.to_datetime(os.path.basename(box_score)[:8], format="%Y%m%d")
    full_game["won"] = full_game["total"] > full_game["total_opp"]

    games.append(full_game)

    if len(games) % 100 == 0:
        print(f"{len(games)} / {len(box_scores)}")
# Out:
# 100 / 12846
# 200 / 12846
# 300 / 12846
# 400 / 12846
# 500 / 12846
# 600 / 12846
# 700 / 12846
# 800 / 12846
# 900 / 12846
# 1000 / 12846
# 1100 / 12846
# ⚠️ Skipping empty file: data/scores\201604010NYK.html
# 1200 / 12846
# 1300 / 12846
# 1400 / 12846
# 1500 / 12846
# 1600 / 12846
# 1700 / 12846
# 1800 / 12846
# 1900 / 12846
# 2000 / 12846
# 2100 / 12846
# 2200 / 12846
# 2300 / 12846
# 2400 / 12846
# 2500 / 12846
# 2600 / 12846
# 2700 / 12846
# 2800 / 12846
# 2900 / 12846
# 3000 / 12846
# 3100 / 12846
# 3200 / 12846
# 3300 / 12846
# 3400 / 12846
# 3500 / 12846
# 3600 / 12846
# 3700 / 12846
# 3800 / 12846
# 3900 / 12846
# 4000 / 12846
# 4100 / 12846
# 4200 / 12846
# 4300 / 12846
# 4400 / 12846
# 4500 / 12846
# 4600 / 12846
# 4700 / 12846
# 4800 / 12846
# 4900 / 12846
# 5000 / 12846
# 5100 / 12846
# 5200 / 12846
# 5300 / 12846
# 5400 / 12846
# 5500 / 12846
# 5600 / 12846
# 5700 / 12846
# 5800 / 12846
# 5900 / 12846
# 6000 / 12846
# 6100 / 12846
# 6200 / 12846
# 6300 / 12846
# 6400 / 12846
# 6500 / 12846
# 6600 / 12846
# 6700 / 12846
# 6800 / 12846
# 6900 / 12846
# 7000 / 12846
# 7100 / 12846
# 7200 / 12846
# 7300 / 12846
# 7400 / 12846
# 7500 / 12846
# 7600 / 12846
# 7700 / 12846
# 7800 / 12846
# 7900 / 12846
# 8000 / 12846
# 8100 / 12846
# 8200 / 12846
# 8300 / 12846
# 8400 / 12846
# 8500 / 12846
# 8600 / 12846
# 8700 / 12846
# 8800 / 12846
# 8900 / 12846
# 9000 / 12846
# 9100 / 12846
# 9200 / 12846
# 9300 / 12846
# 9400 / 12846
# 9500 / 12846
# 9600 / 12846
# 9700 / 12846
# 9800 / 12846
# 9900 / 12846
# 10000 / 12846
# 10100 / 12846
# 10200 / 12846
# 10300 / 12846
# 10400 / 12846
# 10500 / 12846
# 10600 / 12846
# 10700 / 12846
# 10800 / 12846
# 10900 / 12846
# 11000 / 12846
# 11100 / 12846
# 11200 / 12846
# 11300 / 12846
# 11400 / 12846
# 11500 / 12846
# 11600 / 12846
# 11700 / 12846
# 11800 / 12846
# 11900 / 12846
# 12000 / 12846
# 12100 / 12846
# 12200 / 12846
# 12300 / 12846
# 12400 / 12846
# 12500 / 12846
# 12600 / 12846
# 12700 / 12846
# 12800 / 12846

# %%
games_df = pd.concat(games, ignore_index=True)

# %%
[g.shape[1] for g in games if g.shape[1] != 150]
# Out:
# [154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  ...]

# %%
games_df.to_csv("nba_games.csv")

# %%
headers_list = [set(df.columns) for df in games]

# %%
common_headers = set.intersection(*headers_list)
print("Common headers:", len(common_headers))
# Out:
# Common headers: 150

# %%
# collect the "normal" headers (150)
baseline_headers = games[0].columns  # assuming the first game has 150

# look at games that don't have 150 headers
for i, g in enumerate(games):
    if g.shape[1] != 150:
        extras = set(g.columns) - set(baseline_headers)
        print(f"\nGame {i} has {g.shape[1]} headers")
        print("Extra headers:", extras)
# Out:
# Game 0 has 154 headers
# Extra headers: set()
#
# Game 1 has 154 headers
# Extra headers: set()
#
# Game 2 has 154 headers
# Extra headers: set()
#
# Game 3 has 154 headers
# Extra headers: set()
#
# Game 4 has 154 headers
# Extra headers: set()
#
# Game 5 has 154 headers
# Extra headers: set()
#
# Game 6 has 154 headers
# Extra headers: set()
#
# Game 7 has 154 headers
# Extra headers: set()
#
# Game 8 has 154 headers
# Extra headers: set()
#
# Game 9 has 154 headers
# Extra headers: set()
#
# Game 10 has 154 headers
# Extra headers: set()
#
# Game 11 has 154 headers
# Extra headers: set()
#
# Game 12 has 154 headers
# Extra headers: set()
#
# Game 13 has 154 headers
# Extra headers: set()
#
# Game 14 has 154 headers
# Extra headers: set()
#
# Game 15 has 154 headers
# Extra headers: set()
#
# Game 16 has 154 headers
# Extra headers: set()
#
# Game 17 has 154 headers
# Extra headers: set()
#
# Game 18 has 154 headers
# Extra headers: set()
#
# Game 19 has 154 headers
# Extra headers: set()
#
# Game 20 has 154 headers
# Extra headers: set()
#
# Game 21 has 154 headers
# Extra headers: set()
#
# Game 22 has 154 headers
# Extra headers: set()
#
# Game 23 has 154 headers
# Extra headers: set()
#
# Game 24 has 154 headers
# Extra headers: set()
#
# Game 25 has 154 headers
# Extra headers: set()
#
# Game 26 has 154 headers
# Extra headers: set()
#
# Game 27 has 154 headers
# Extra headers: set()
#
# Game 28 has 154 headers
# Extra headers: set()
#
# Game 29 has 154 headers
# Extra headers: set()
#
# Game 30 has 154 headers
# Extra headers: set()
#
# Game 31 has 154 headers
# Extra headers: set()
#
# Game 32 has 154 headers
# Extra headers: set()
#
# Game 33 has 154 headers
# Extra headers: set()
#
# Game 34 has 154 headers
# Extra headers: set()
#
# Game 35 has 154 headers
# Extra headers: set()
#
# Game 36 has 154 headers
# Extra headers: set()
#
# Game 37 has 154 headers
# Extra headers: set()
#
# Game 38 has 154 headers
# Extra headers: set()
#
# Game 39 has 154 headers
# Extra headers: set()
#
# Game 40 has 154 headers
# Extra headers: set()
#
# Game 41 has 154 headers
# Extra headers: set()
#
# Game 42 has 154 headers
# Extra headers: set()
#
# Game 43 has 154 headers
# Extra headers: set()
#
# Game 44 has 154 headers
# Extra headers: set()
#
# Game 45 has 154 headers
# Extra headers: set()
#
# Game 46 has 154 headers
# Extra headers: set()
#
# Game 47 has 154 headers
# Extra headers: set()
#
# Game 48 has 154 headers
# Extra headers: set()
#
# Game 49 has 154 headers
# Extra headers: set()
#
# Game 50 has 154 headers
# Extra headers: set()
#
# Game 51 has 154 headers
# Extra headers: set()
#
# Game 52 has 154 headers
# Extra headers: set()
#
# Game 53 has 154 headers
# Extra headers: set()
#
# Game 54 has 154 headers
# Extra headers: set()
#
# Game 55 has 154 headers
# Extra headers: set()
#
# Game 56 has 154 headers
# Extra headers: set()
#
# Game 57 has 154 headers
# Extra headers: set()
#
# Game 58 has 154 headers
# Extra headers: set()
#
# Game 59 has 154 headers
# Extra headers: set()
#
# Game 60 has 154 headers
# Extra headers: set()
#
# Game 61 has 154 headers
# Extra headers: set()
#
# Game 62 has 154 headers
# Extra headers: set()
#
# Game 63 has 154 headers
# Extra headers: set()
#
# Game 64 has 154 headers
# Extra headers: set()
#
# Game 65 has 154 headers
# Extra headers: set()
#
# Game 66 has 154 headers
# Extra headers: set()
#
# Game 67 has 154 headers
# Extra headers: set()
#
# Game 68 has 154 headers
# Extra headers: set()
#
# Game 69 has 154 headers
# Extra headers: set()
#
# Game 70 has 154 headers
# Extra headers: set()
#
# Game 71 has 154 headers
# Extra headers: set()
#
# Game 72 has 154 headers
# Extra headers: set()
#
# Game 73 has 154 headers
# Extra headers: set()
#
# Game 74 has 154 headers
# Extra headers: set()
#
# Game 75 has 154 headers
# Extra headers: set()
#
# Game 76 has 154 headers
# Extra headers: set()
#
# Game 77 has 154 headers
# Extra headers: set()
#
# Game 78 has 154 headers
# Extra headers: set()
#
# Game 79 has 154 headers
# Extra headers: set()
#
# Game 80 has 154 headers
# Extra headers: set()
#
# Game 81 has 154 headers
# Extra headers: set()
#
# Game 82 has 154 headers
# Extra headers: set()
#
# Game 83 has 154 headers
# Extra headers: set()
#
# Game 84 has 154 headers
# Extra headers: set()
#
# Game 85 has 154 headers
# Extra headers: set()
#
# Game 86 has 154 headers
# Extra headers: set()
#
# Game 87 has 154 headers
# Extra headers: set()
#
# Game 88 has 154 headers
# Extra headers: set()
#
# Game 89 has 154 headers
# Extra headers: set()
#
# Game 90 has 154 headers
# Extra headers: set()
#
# Game 91 has 154 headers
# Extra headers: set()
#
# Game 92 has 154 headers
# Extra headers: set()
#
# Game 93 has 154 headers
# Extra headers: set()
#
# Game 94 has 154 headers
# Extra headers: set()
#
# Game 95 has 154 headers
# Extra headers: set()
#
# Game 96 has 154 headers
# Extra headers: set()
#
# Game 97 has 154 headers
# Extra headers: set()
#
# Game 98 has 154 headers
# Extra headers: set()
#
# Game 99 has 154 headers
# Extra headers: set()
#
# Game 100 has 154 headers
# Extra headers: set()
#
# Game 101 has 154 headers
# Extra headers: set()
#
# Game 102 has 154 headers
# Extra headers: set()
#
# Game 103 has 154 headers
# Extra headers: set()
#
# Game 104 has 154 headers
# Extra headers: set()
#
# Game 105 has 154 headers
# Extra headers: set()
#
# Game 106 has 154 headers
# Extra headers: set()
#
# Game 107 has 154 headers
# Extra headers: set()
#
# Game 108 has 154 headers
# Extra headers: set()
#
# Game 109 has 154 headers
# Extra headers: set()
#
# Game 110 has 154 headers
# Extra headers: set()
#
# Game 111 has 154 headers
# Extra headers: set()
#
# Game 112 has 154 headers
# Extra headers: set()
#
# Game 113 has 154 headers
# Extra headers: set()
#
# Game 114 has 154 headers
# Extra headers: set()
#
# Game 115 has 154 headers
# Extra headers: set()
#
# Game 116 has 154 headers
# Extra headers: set()
#
# Game 117 has 154 headers
# Extra headers: set()
#
# Game 118 has 154 headers
# Extra headers: set()
#
# Game 119 has 154 headers
# Extra headers: set()
#
# Game 120 has 154 headers
# Extra headers: set()
#
# Game 121 has 154 headers
# Extra headers: set()
#
# Game 122 has 154 headers
# Extra headers: set()
#
# Game 123 has 154 headers
# Extra headers: set()
#
# Game 124 has 154 headers
# Extra headers: set()
#
# Game 125 has 154 headers
# Extra headers: set()
#
# Game 126 has 154 headers
# Extra headers: set()
#
# Game 127 has 154 headers
# Extra headers: set()
#
# Game 128 has 154 headers
# Extra headers: set()
#
# Game 129 has 154 headers
# Extra headers: set()
#
# Game 130 has 154 headers
# Extra headers: set()
#
# Game 131 has 154 headers
# Extra headers: set()
#
# Game 132 has 154 headers
# Extra headers: set()
#
# Game 133 has 154 headers
# Extra headers: set()
#
# Game 134 has 154 headers
# Extra headers: set()
#
# Game 135 has 154 headers
# Extra headers: set()
#
# Game 136 has 154 headers
# Extra headers: set()
#
# Game 137 has 154 headers
# Extra headers: set()
#
# Game 138 has 154 headers
# Extra headers: set()
#
# Game 139 has 154 headers
# Extra headers: set()
#
# Game 140 has 154 headers
# Extra headers: set()
#
# Game 141 has 154 headers
# Extra headers: set()
#
# Game 142 has 154 headers
# Extra headers: set()
#
# Game 143 has 154 headers
# Extra headers: set()
#
# Game 144 has 154 headers
# Extra headers: set()
#
# Game 145 has 154 headers
# Extra headers: set()
#
# Game 146 has 154 headers
# Extra headers: set()
#
# Game 147 has 154 headers
# Extra headers: set()
#
# Game 148 has 154 headers
# Extra headers: set()
#
# Game 149 has 154 headers
# Extra headers: set()
#
# Game 150 has 154 headers
# Extra headers: set()
#
# Game 151 has 154 headers
# Extra headers: set()
#
# Game 152 has 154 headers
# Extra headers: set()
#
# Game 153 has 154 headers
# Extra headers: set()
#
# Game 154 has 154 headers
# Extra headers: set()
#
# Game 155 has 154 headers
# Extra headers: set()
#
# Game 156 has 154 headers
# Extra headers: set()
#
# Game 157 has 154 headers
# Extra headers: set()
#
# Game 158 has 154 headers
# Extra headers: set()
#
# Game 159 has 154 headers
# Extra headers: set()
#
# Game 160 has 154 headers
# Extra headers: set()
#
# Game 161 has 154 headers
# Extra headers: set()
#
# Game 162 has 154 headers
# Extra headers: set()
#
# Game 163 has 154 headers
# Extra headers: set()
#
# Game 164 has 154 headers
# Extra headers: set()
#
# Game 165 has 154 headers
# Extra headers: set()
#
# Game 166 has 154 headers
# Extra headers: set()
#
# Game 167 has 154 headers
# Extra headers: set()
#
# Game 168 has 154 headers
# Extra headers: set()
#
# Game 169 has 154 headers
# Extra headers: set()
#
# Game 170 has 154 headers
# Extra headers: set()
#
# Game 171 has 154 headers
# Extra headers: set()
#
# Game 172 has 154 headers
# Extra headers: set()
#
# Game 173 has 154 headers
# Extra headers: set()
#
# Game 174 has 154 headers
# Extra headers: set()
#
# Game 175 has 154 headers
# Extra headers: set()
#
# Game 176 has 154 headers
# Extra headers: set()
#
# Game 177 has 154 headers
# Extra headers: set()
#
# Game 178 has 154 headers
# Extra headers: set()
#
# Game 179 has 154 headers
# Extra headers: set()
#
# Game 180 has 154 headers
# Extra headers: set()
#
# Game 181 has 154 headers
# Extra headers: set()
#
# Game 182 has 154 headers
# Extra headers: set()
#
# Game 183 has 154 headers
# Extra headers: set()
#
# Game 184 has 154 headers
# Extra headers: set()
#
# Game 185 has 154 headers
# Extra headers: set()
#
# Game 186 has 154 headers
# Extra headers: set()
#
# Game 187 has 154 headers
# Extra headers: set()
#
# Game 188 has 154 headers
# Extra headers: set()
#
# Game 189 has 154 headers
# Extra headers: set()
#
# Game 190 has 154 headers
# Extra headers: set()
#
# Game 191 has 154 headers
# Extra headers: set()
#
# Game 192 has 154 headers
# Extra headers: set()
#
# Game 193 has 154 headers
# Extra headers: set()
#
# Game 194 has 154 headers
# Extra headers: set()
#
# Game 195 has 154 headers
# Extra headers: set()
#
# Game 196 has 154 headers
# Extra headers: set()
#
# Game 197 has 154 headers
# Extra headers: set()
#
# Game 198 has 154 headers
# Extra headers: set()
#
# Game 199 has 154 headers
# Extra headers: set()
#
# Game 200 has 154 headers
# Extra headers: set()
#
# Game 201 has 154 headers
# Extra headers: set()
#
# Game 202 has 154 headers
# Extra headers: set()
#
# Game 203 has 154 headers
# Extra headers: set()
#
# Game 204 has 154 headers
# Extra headers: set()
#
# Game 205 has 154 headers
# Extra headers: set()
#
# Game 206 has 154 headers
# Extra headers: set()
#
# Game 207 has 154 headers
# Extra headers: set()
#
# Game 208 has 154 headers
# Extra headers: set()
#
# Game 209 has 154 headers
# Extra headers: set()
#
# Game 210 has 154 headers
# Extra headers: set()
#
# Game 211 has 154 headers
# Extra headers: set()
#
# Game 212 has 154 headers
# Extra headers: set()
#
# Game 213 has 154 headers
# Extra headers: set()
#
# Game 214 has 154 headers
# Extra headers: set()
#
# Game 215 has 154 headers
# Extra headers: set()
#
# Game 216 has 154 headers
# Extra headers: set()
#
# Game 217 has 154 headers
# Extra headers: set()
#
# Game 218 has 154 headers
# Extra headers: set()
#
# Game 219 has 154 headers
# Extra headers: set()
#
# Game 220 has 154 headers
# Extra headers: set()
#
# Game 221 has 154 headers
# Extra headers: set()
#
# Game 222 has 154 headers
# Extra headers: set()
#
# Game 223 has 154 headers
# Extra headers: set()
#
# Game 224 has 154 headers
# Extra headers: set()
#
# Game 225 has 154 headers
# Extra headers: set()
#
# Game 226 has 154 headers
# Extra headers: set()
#
# Game 227 has 154 headers
# Extra headers: set()
#
# Game 228 has 154 headers
# Extra headers: set()
#
# Game 229 has 154 headers
# Extra headers: set()
#
# Game 230 has 154 headers
# Extra headers: set()
#
# Game 231 has 154 headers
# Extra headers: set()
#
# Game 232 has 154 headers
# Extra headers: set()
#
# Game 233 has 154 headers
# Extra headers: set()
#
# Game 234 has 154 headers
# Extra headers: set()
#
# Game 235 has 154 headers
# Extra headers: set()
#
# Game 236 has 154 headers
# Extra headers: set()
#
# Game 237 has 154 headers
# Extra headers: set()
#
# Game 238 has 154 headers
# Extra headers: set()
#
# Game 239 has 154 headers
# Extra headers: set()
#
# Game 240 has 154 headers
# Extra headers: set()
#
# Game 241 has 154 headers
# Extra headers: set()
#
# Game 242 has 154 headers
# Extra headers: set()
#
# Game 243 has 154 headers
# Extra headers: set()
#
# Game 244 has 154 headers
# Extra headers: set()
#
# Game 245 has 154 headers
# Extra headers: set()
#
# Game 246 has 154 headers
# Extra headers: set()
#
# Game 247 has 154 headers
# Extra headers: set()
#
# Game 248 has 154 headers
# Extra headers: set()
#
# Game 249 has 154 headers
# Extra headers: set()
#
# Game 250 has 154 headers
# Extra headers: set()
#
# Game 251 has 154 headers
# Extra headers: set()
#
# Game 252 has 154 headers
# Extra headers: set()
#
# Game 253 has 154 headers
# Extra headers: set()
#
# Game 254 has 154 headers
# Extra headers: set()
#
# Game 255 has 154 headers
# Extra headers: set()
#
# Game 256 has 154 headers
# Extra headers: set()
#
# Game 257 has 154 headers
# Extra headers: set()
#
# Game 258 has 154 headers
# Extra headers: set()
#
# Game 259 has 154 headers
# Extra headers: set()
#
# Game 260 has 154 headers
# Extra headers: set()
#
# Game 261 has 154 headers
# Extra headers: set()
#
# Game 262 has 154 headers
# Extra headers: set()
#
# Game 263 has 154 headers
# Extra headers: set()
#
# Game 264 has 154 headers
# Extra headers: set()
#
# Game 265 has 154 headers
# Extra headers: set()
#
# Game 266 has 154 headers
# Extra headers: set()
#
# Game 267 has 154 headers
# Extra headers: set()
#
# Game 268 has 154 headers
# Extra headers: set()
#
# Game 269 has 154 headers
# Extra headers: set()
#
# Game 270 has 154 headers
# Extra headers: set()
#
# Game 271 has 154 headers
# Extra headers: set()
#
# Game 272 has 154 headers
# Extra headers: set()
#
# Game 273 has 154 headers
# Extra headers: set()
#
# Game 274 has 154 headers
# Extra headers: set()
#
# Game 275 has 154 headers
# Extra headers: set()
#
# Game 276 has 154 headers
# Extra headers: set()
#
# Game 277 has 154 headers
# Extra headers: set()
#
# Game 278 has 154 headers
# Extra headers: set()
#
# Game 279 has 154 headers
# Extra headers: set()
#
# Game 280 has 154 headers
# Extra headers: set()
#
# Game 281 has 154 headers
# Extra headers: set()
#
# Game 282 has 154 headers
# Extra headers: set()
#
# Game 283 has 154 headers
# Extra headers: set()
#
# Game 284 has 154 headers
# Extra headers: set()
#
# Game 285 has 154 headers
# Extra headers: set()
#
# Game 286 has 154 headers
# Extra headers: set()
#
# Game 287 has 154 headers
# Extra headers: set()
#
# Game 288 has 154 headers
# Extra headers: set()
#
# Game 289 has 154 headers
# Extra headers: set()
#
# Game 290 has 154 headers
# Extra headers: set()
#
# Game 291 has 154 headers
# Extra headers: set()
#
# Game 292 has 154 headers
# Extra headers: set()
#
# Game 293 has 154 headers
# Extra headers: set()
#
# Game 294 has 154 headers
# Extra headers: set()
#
# Game 295 has 154 headers
# Extra headers: set()
#
# Game 296 has 154 headers
# Extra headers: set()
#
# Game 297 has 154 headers
# Extra headers: set()
#
# Game 298 has 154 headers
# Extra headers: set()
#
# Game 299 has 154 headers
# Extra headers: set()
#
# Game 300 has 154 headers
# Extra headers: set()
#
# Game 301 has 154 headers
# Extra headers: set()
#
# Game 302 has 154 headers
# Extra headers: set()
#
# Game 303 has 154 headers
# Extra headers: set()
#
# Game 304 has 154 headers
# Extra headers: set()
#
# Game 305 has 154 headers
# Extra headers: set()
#
# Game 306 has 154 headers
# Extra headers: set()
#
# Game 307 has 154 headers
# Extra headers: set()
#
# Game 308 has 154 headers
# Extra headers: set()
#
# Game 309 has 154 headers
# Extra headers: set()
#
# Game 310 has 154 headers
# Extra headers: set()
#
# Game 311 has 154 headers
# Extra headers: set()
#
# Game 312 has 154 headers
# Extra headers: set()
#
# Game 313 has 154 headers
# Extra headers: set()
#
# Game 314 has 154 headers
# Extra headers: set()
#
# Game 315 has 154 headers
# Extra headers: set()
#
# Game 316 has 154 headers
# Extra headers: set()
#
# Game 317 has 154 headers
# Extra headers: set()
#
# Game 318 has 154 headers
# Extra headers: set()
#
# Game 319 has 154 headers
# Extra headers: set()
#
# Game 320 has 154 headers
# Extra headers: set()
#
# Game 321 has 154 headers
# Extra headers: set()
#
# Game 322 has 154 headers
# Extra headers: set()
#
# Game 323 has 154 headers
# Extra headers: set()
#
# Game 324 has 154 headers
# Extra headers: set()
#
# Game 325 has 154 headers
# Extra headers: set()
#
# Game 326 has 154 headers
# Extra headers: set()
#
# Game 327 has 154 headers
# Extra headers: set()
#
# Game 328 has 154 headers
# Extra headers: set()
#
# Game 329 has 154 headers
# Extra headers: set()
#
# Game 330 has 154 headers
# Extra headers: set()
#
# Game 331 has 154 headers
# Extra headers: set()
#
# Game 332 has 154 headers
# Extra headers: set()
#
# Game 333 has 154 headers
# Extra headers: set()
#
# Game 334 has 154 headers
# Extra headers: set()
#
# Game 335 has 154 headers
# Extra headers: set()
#
# Game 336 has 154 headers
# Extra headers: set()
#
# Game 337 has 154 headers
# Extra headers: set()
#
# Game 338 has 154 headers
# Extra headers: set()
#
# Game 339 has 154 headers
# Extra headers: set()
#
# Game 340 has 154 headers
# Extra headers: set()
#
# Game 341 has 154 headers
# Extra headers: set()
#
# Game 342 has 154 headers
# Extra headers: set()
#
# Game 343 has 154 headers
# Extra headers: set()
#
# Game 344 has 154 headers
# Extra headers: set()
#
# Game 345 has 154 headers
# Extra headers: set()
#
# Game 346 has 154 headers
# Extra headers: set()
#
# Game 347 has 154 headers
# Extra headers: set()
#
# Game 348 has 154 headers
# Extra headers: set()
#
# Game 349 has 154 headers
# Extra headers: set()
#
# Game 350 has 154 headers
# Extra headers: set()
#
# Game 351 has 154 headers
# Extra headers: set()
#
# Game 352 has 154 headers
# Extra headers: set()
#
# Game 353 has 154 headers
# Extra headers: set()
#
# Game 354 has 154 headers
# Extra headers: set()
#
# Game 355 has 154 headers
# Extra headers: set()
#
# Game 356 has 154 headers
# Extra headers: set()
#
# Game 357 has 154 headers
# Extra headers: set()
#
# Game 358 has 154 headers
# Extra headers: set()
#
# Game 359 has 154 headers
# Extra headers: set()
#
# Game 360 has 154 headers
# Extra headers: set()
#
# Game 361 has 154 headers
# Extra headers: set()
#
# Game 362 has 154 headers
# Extra headers: set()
#
# Game 363 has 154 headers
# Extra headers: set()
#
# Game 364 has 154 headers
# Extra headers: set()
#
# Game 365 has 154 headers
# Extra headers: set()
#
# Game 366 has 154 headers
# Extra headers: set()
#
# Game 367 has 154 headers
# Extra headers: set()
#
# Game 368 has 154 headers
# Extra headers: set()
#
# Game 369 has 154 headers
# Extra headers: set()
#
# Game 370 has 154 headers
# Extra headers: set()
#
# Game 371 has 154 headers
# Extra headers: set()
#
# Game 372 has 154 headers
# Extra headers: set()
#
# Game 373 has 154 headers
# Extra headers: set()
#
# Game 374 has 154 headers
# Extra headers: set()
#
# Game 375 has 154 headers
# Extra headers: set()
#
# Game 376 has 154 headers
# Extra headers: set()
#
# Game 377 has 154 headers
# Extra headers: set()
#
# Game 378 has 154 headers
# Extra headers: set()
#
# Game 379 has 154 headers
# Extra headers: set()
#
# Game 380 has 154 headers
# Extra headers: set()
#
# Game 381 has 154 headers
# Extra headers: set()
#
# Game 382 has 154 headers
# Extra headers: set()
#
# Game 383 has 154 headers
# Extra headers: set()
#
# Game 384 has 154 headers
# Extra headers: set()
#
# Game 385 has 154 headers
# Extra headers: set()
#
# Game 386 has 154 headers
# Extra headers: set()
#
# Game 387 has 154 headers
# Extra headers: set()
#
# Game 388 has 154 headers
# Extra headers: set()
#
# Game 389 has 154 headers
# Extra headers: set()
#
# Game 390 has 154 headers
# Extra headers: set()
#
# Game 391 has 154 headers
# Extra headers: set()
#
# Game 392 has 154 headers
# Extra headers: set()
#
# Game 393 has 154 headers
# Extra headers: set()
#
# Game 394 has 154 headers
# Extra headers: set()
#
# Game 395 has 154 headers
# Extra headers: set()
#
# Game 396 has 154 headers
# Extra headers: set()
#
# Game 397 has 154 headers
# Extra headers: set()
#
# Game 398 has 154 headers
# Extra headers: set()
#
# Game 399 has 154 headers
# Extra headers: set()
#
# Game 400 has 154 headers
# Extra headers: set()
#
# Game 401 has 154 headers
# Extra headers: set()
#
# Game 402 has 154 headers
# Extra headers: set()
#
# Game 403 has 154 headers
# Extra headers: set()
#
# Game 404 has 154 headers
# Extra headers: set()
#
# Game 405 has 154 headers
# Extra headers: set()
#
# Game 406 has 154 headers
# Extra headers: set()
#
# Game 407 has 154 headers
# Extra headers: set()
#
# Game 408 has 154 headers
# Extra headers: set()
#
# Game 409 has 154 headers
# Extra headers: set()
#
# Game 410 has 154 headers
# Extra headers: set()
#
# Game 411 has 154 headers
# Extra headers: set()
#
# Game 412 has 154 headers
# Extra headers: set()
#
# Game 413 has 154 headers
# Extra headers: set()
#
# Game 414 has 154 headers
# Extra headers: set()
#
# Game 415 has 154 headers
# Extra headers: set()
#
# Game 416 has 154 headers
# Extra headers: set()
#
# Game 417 has 154 headers
# Extra headers: set()
#
# Game 418 has 154 headers
# Extra headers: set()
#
# Game 419 has 154 headers
# Extra headers: set()
#
# Game 420 has 154 headers
# Extra headers: set()
#
# Game 421 has 154 headers
# Extra headers: set()
#
# Game 422 has 154 headers
# Extra headers: set()
#
# Game 423 has 154 headers
# Extra headers: set()
#
# Game 424 has 154 headers
# Extra headers: set()
#
# Game 425 has 154 headers
# Extra headers: set()
#
# Game 426 has 154 headers
# Extra headers: set()
#
# Game 427 has 154 headers
# Extra headers: set()
#
# Game 428 has 154 headers
# Extra headers: set()
#
# Game 429 has 154 headers
# Extra headers: set()
#
# Game 430 has 154 headers
# Extra headers: set()
#
# Game 431 has 154 headers
# Extra headers: set()
#
# Game 432 has 154 headers
# Extra headers: set()
#
# Game 433 has 154 headers
# Extra headers: set()
#
# Game 434 has 154 headers
# Extra headers: set()
#
# Game 435 has 154 headers
# Extra headers: set()
#
# Game 436 has 154 headers
# Extra headers: set()
#
# Game 437 has 154 headers
# Extra headers: set()
#
# Game 438 has 154 headers
# Extra headers: set()
#
# Game 439 has 154 headers
# Extra headers: set()
#
# Game 440 has 154 headers
# Extra headers: set()
#
# Game 441 has 154 headers
# Extra headers: set()
#
# Game 442 has 154 headers
# Extra headers: set()
#
# Game 443 has 154 headers
# Extra headers: set()
#
# Game 444 has 154 headers
# Extra headers: set()
#
# Game 445 has 154 headers
# Extra headers: set()
#
# Game 446 has 154 headers
# Extra headers: set()
#
# Game 447 has 154 headers
# Extra headers: set()
#
# Game 448 has 154 headers
# Extra headers: set()
#
# Game 449 has 154 headers
# Extra headers: set()
#
# Game 450 has 154 headers
# Extra headers: set()
#
# Game 451 has 154 headers
# Extra headers: set()
#
# Game 452 has 154 headers
# Extra headers: set()
#
# Game 453 has 154 headers
# Extra headers: set()
#
# Game 454 has 154 headers
# Extra headers: set()
#
# Game 455 has 154 headers
# Extra headers: set()
#
# Game 456 has 154 headers
# Extra headers: set()
#
# Game 457 has 154 headers
# Extra headers: set()
#
# Game 458 has 154 headers
# Extra headers: set()
#
# Game 459 has 154 headers
# Extra headers: set()
#
# Game 460 has 154 headers
# Extra headers: set()
#
# Game 461 has 154 headers
# Extra headers: set()
#
# Game 462 has 154 headers
# Extra headers: set()
#
# Game 463 has 154 headers
# Extra headers: set()
#
# Game 464 has 154 headers
# Extra headers: set()
#
# Game 465 has 154 headers
# Extra headers: set()
#
# Game 466 has 154 headers
# Extra headers: set()
#
# Game 467 has 154 headers
# Extra headers: set()
#
# Game 468 has 154 headers
# Extra headers: set()
#
# Game 469 has 154 headers
# Extra headers: set()
#
# Game 470 has 154 headers
# Extra headers: set()
#
# Game 471 has 154 headers
# Extra headers: set()
#
# Game 472 has 154 headers
# Extra headers: set()
#
# Game 473 has 154 headers
# Extra headers: set()
#
# Game 474 has 154 headers
# Extra headers: set()
#
# Game 475 has 154 headers
# Extra headers: set()
#
# Game 476 has 154 headers
# Extra headers: set()
#
# Game 477 has 154 headers
# Extra headers: set()
#
# Game 478 has 154 headers
# Extra headers: set()
#
# Game 479 has 154 headers
# Extra headers: set()
#
# Game 480 has 154 headers
# Extra headers: set()
#
# Game 481 has 154 headers
# Extra headers: set()
#
# Game 482 has 154 headers
# Extra headers: set()
#
# Game 483 has 154 headers
# Extra headers: set()
#
# Game 484 has 154 headers
# Extra headers: set()
#
# Game 485 has 154 headers
# Extra headers: set()
#
# Game 486 has 154 headers
# Extra headers: set()
#
# Game 487 has 154 headers
# Extra headers: set()
#
# Game 488 has 154 headers
# Extra headers: set()
#
# Game 489 has 154 headers
# Extra headers: set()
#
# Game 490 has 154 headers
# Extra headers: set()
#
# Game 491 has 154 headers
# Extra headers: set()
#
# Game 492 has 154 headers
# Extra headers: set()
#
# Game 493 has 154 headers
# Extra headers: set()
#
# Game 494 has 154 headers
# Extra headers: set()
#
# Game 495 has 154 headers
# Extra headers: set()
#
# Game 496 has 154 headers
# Extra headers: set()
#
# Game 497 has 154 headers
# Extra headers: set()
#
# Game 498 has 154 headers
# Extra headers: set()
#
# Game 499 has 154 headers
# Extra headers: set()
#
# Game 500 has 154 headers
# Extra headers: set()
#
# Game 501 has 154 headers
# Extra headers: set()
#
# Game 502 has 154 headers
# Extra headers: set()
#
# Game 503 has 154 headers
# Extra headers: set()
#
# Game 504 has 154 headers
# Extra headers: set()
#
# Game 505 has 154 headers
# Extra headers: set()
#
# Game 506 has 154 headers
# Extra headers: set()
#
# Game 507 has 154 headers
# Extra headers: set()
#
# Game 508 has 154 headers
# Extra headers: set()
#
# Game 509 has 154 headers
# Extra headers: set()
#
# Game 510 has 154 headers
# Extra headers: set()
#
# Game 511 has 154 headers
# Extra headers: set()
#
# Game 512 has 154 headers
# Extra headers: set()
#
# Game 513 has 154 headers
# Extra headers: set()
#
# Game 514 has 154 headers
# Extra headers: set()
#
# Game 515 has 154 headers
# Extra headers: set()
#
# Game 516 has 154 headers
# Extra headers: set()
#
# Game 517 has 154 headers
# Extra headers: set()
#
# Game 518 has 154 headers
# Extra headers: set()
#
# Game 519 has 154 headers
# Extra headers: set()
#
# Game 520 has 154 headers
# Extra headers: set()
#
# Game 521 has 154 headers
# Extra headers: set()
#
# Game 522 has 154 headers
# Extra headers: set()
#
# Game 523 has 154 headers
# Extra headers: set()
#
# Game 524 has 154 headers
# Extra headers: set()
#
# Game 525 has 154 headers
# Extra headers: set()
#
# Game 526 has 154 headers
# Extra headers: set()
#
# Game 527 has 154 headers
# Extra headers: set()
#
# Game 528 has 154 headers
# Extra headers: set()
#
# Game 529 has 154 headers
# Extra headers: set()
#
# Game 530 has 154 headers
# Extra headers: set()
#
# Game 531 has 154 headers
# Extra headers: set()
#
# Game 532 has 154 headers
# Extra headers: set()
#
# Game 533 has 154 headers
# Extra headers: set()
#
# Game 534 has 154 headers
# Extra headers: set()
#
# Game 535 has 154 headers
# Extra headers: set()
#
# Game 536 has 154 headers
# Extra headers: set()
#
# Game 537 has 154 headers
# Extra headers: set()
#
# Game 538 has 154 headers
# Extra headers: set()
#
# Game 539 has 154 headers
# Extra headers: set()
#
# Game 540 has 154 headers
# Extra headers: set()
#
# Game 541 has 154 headers
# Extra headers: set()
#
# Game 542 has 154 headers
# Extra headers: set()
#
# Game 543 has 154 headers
# Extra headers: set()
#
# Game 544 has 154 headers
# Extra headers: set()
#
# Game 545 has 154 headers
# Extra headers: set()
#
# Game 546 has 154 headers
# Extra headers: set()
#
# Game 547 has 154 headers
# Extra headers: set()
#
# Game 548 has 154 headers
# Extra headers: set()
#
# Game 549 has 154 headers
# Extra headers: set()
#
# Game 550 has 154 headers
# Extra headers: set()
#
# Game 551 has 154 headers
# Extra headers: set()
#
# Game 552 has 154 headers
# Extra headers: set()
#
# Game 553 has 154 headers
# Extra headers: set()
#
# Game 554 has 154 headers
# Extra headers: set()
#
# Game 555 has 154 headers
# Extra headers: set()
#
# Game 556 has 154 headers
# Extra headers: set()
#
# Game 557 has 154 headers
# Extra headers: set()
#
# Game 558 has 154 headers
# Extra headers: set()
#
# Game 559 has 154 headers
# Extra headers: set()
#
# Game 560 has 154 headers
# Extra headers: set()
#
# Game 561 has 154 headers
# Extra headers: set()
#
# Game 562 has 154 headers
# Extra headers: set()
#
# Game 563 has 154 headers
# Extra headers: set()
#
# Game 564 has 154 headers
# Extra headers: set()
#
# Game 565 has 154 headers
# Extra headers: set()
#
# Game 566 has 154 headers
# Extra headers: set()
#
# Game 567 has 154 headers
# Extra headers: set()
#
# Game 568 has 154 headers
# Extra headers: set()
#
# Game 569 has 154 headers
# Extra headers: set()
#
# Game 570 has 154 headers
# Extra headers: set()
#
# Game 571 has 154 headers
# Extra headers: set()
#
# Game 572 has 154 headers
# Extra headers: set()
#
# Game 573 has 154 headers
# Extra headers: set()
#
# Game 574 has 154 headers
# Extra headers: set()
#
# Game 575 has 154 headers
# Extra headers: set()
#
# Game 576 has 154 headers
# Extra headers: set()
#
# Game 577 has 154 headers
# Extra headers: set()
#
# Game 578 has 154 headers
# Extra headers: set()
#
# Game 579 has 154 headers
# Extra headers: set()
#
# Game 580 has 154 headers
# Extra headers: set()
#
# Game 581 has 154 headers
# Extra headers: set()
#
# Game 582 has 154 headers
# Extra headers: set()
#
# Game 583 has 154 headers
# Extra headers: set()
#
# Game 584 has 154 headers
# Extra headers: set()
#
# Game 585 has 154 headers
# Extra headers: set()
#
# Game 586 has 154 headers
# Extra headers: set()
#
# Game 587 has 154 headers
# Extra headers: set()
#
# Game 588 has 154 headers
# Extra headers: set()
#
# Game 589 has 154 headers
# Extra headers: set()
#
# Game 590 has 154 headers
# Extra headers: set()
#
# Game 591 has 154 headers
# Extra headers: set()
#
# Game 592 has 154 headers
# Extra headers: set()
#
# Game 593 has 154 headers
# Extra headers: set()
#
# Game 594 has 154 headers
# Extra headers: set()
#
# Game 595 has 154 headers
# Extra headers: set()
#
# Game 596 has 154 headers
# Extra headers: set()
#
# Game 597 has 154 headers
# Extra headers: set()
#
# Game 598 has 154 headers
# Extra headers: set()
#
# Game 599 has 154 headers
# Extra headers: set()
#
# Game 600 has 154 headers
# Extra headers: set()
#
# Game 601 has 154 headers
# Extra headers: set()
#
# Game 602 has 154 headers
# Extra headers: set()
#
# Game 603 has 154 headers
# Extra headers: set()
#
# Game 604 has 154 headers
# Extra headers: set()
#
# Game 605 has 154 headers
# Extra headers: set()
#
# Game 606 has 154 headers
# Extra headers: set()
#
# Game 607 has 154 headers
# Extra headers: set()
#
# Game 608 has 154 headers
# Extra headers: set()
#
# Game 609 has 154 headers
# Extra headers: set()
#
# Game 610 has 154 headers
# Extra headers: set()
#
# Game 611 has 154 headers
# Extra headers: set()
#
# Game 612 has 154 headers
# Extra headers: set()
#
# Game 613 has 154 headers
# Extra headers: set()
#
# Game 614 has 154 headers
# Extra headers: set()
#
# Game 615 has 154 headers
# Extra headers: set()
#
# Game 616 has 154 headers
# Extra headers: set()
#
# Game 617 has 154 headers
# Extra headers: set()
#
# Game 618 has 154 headers
# Extra headers: set()
#
# Game 619 has 154 headers
# Extra headers: set()
#
# Game 620 has 154 headers
# Extra headers: set()
#
# Game 621 has 154 headers
# Extra headers: set()
#
# Game 622 has 154 headers
# Extra headers: set()
#
# Game 623 has 154 headers
# Extra headers: set()
#
# Game 624 has 154 headers
# Extra headers: set()
#
# Game 625 has 154 headers
# Extra headers: set()
#
# Game 626 has 154 headers
# Extra headers: set()
#
# Game 627 has 154 headers
# Extra headers: set()
#
# Game 628 has 154 headers
# Extra headers: set()
#
# Game 629 has 154 headers
# Extra headers: set()
#
# Game 630 has 154 headers
# Extra headers: set()
#
# Game 631 has 154 headers
# Extra headers: set()
#
# Game 632 has 154 headers
# Extra headers: set()
#
# Game 633 has 154 headers
# Extra headers: set()
#
# Game 634 has 154 headers
# Extra headers: set()
#
# Game 635 has 154 headers
# Extra headers: set()
#
# Game 636 has 154 headers
# Extra headers: set()
#
# Game 637 has 154 headers
# Extra headers: set()
#
# Game 638 has 154 headers
# Extra headers: set()
#
# Game 639 has 154 headers
# Extra headers: set()
#
# Game 640 has 154 headers
# Extra headers: set()
#
# Game 641 has 154 headers
# Extra headers: set()
#
# Game 642 has 154 headers
# Extra headers: set()
#
# Game 643 has 154 headers
# Extra headers: set()
#
# Game 644 has 154 headers
# Extra headers: set()
#
# Game 645 has 154 headers
# Extra headers: set()
#
# Game 646 has 154 headers
# Extra headers: set()
#
# Game 647 has 154 headers
# Extra headers: set()
#
# Game 648 has 154 headers
# Extra headers: set()
#
# Game 649 has 154 headers
# Extra headers: set()
#
# Game 650 has 154 headers
# Extra headers: set()
#
# Game 651 has 154 headers
# Extra headers: set()
#
# Game 652 has 154 headers
# Extra headers: set()
#
# Game 653 has 154 headers
# Extra headers: set()
#
# Game 654 has 154 headers
# Extra headers: set()
#
# Game 655 has 154 headers
# Extra headers: set()
#
# Game 656 has 154 headers
# Extra headers: set()
#
# Game 657 has 154 headers
# Extra headers: set()
#
# Game 658 has 154 headers
# Extra headers: set()
#
# Game 659 has 154 headers
# Extra headers: set()
#
# Game 660 has 154 headers
# Extra headers: set()
#
# Game 661 has 154 headers
# Extra headers: set()
#
# Game 662 has 154 headers
# Extra headers: set()
#
# Game 663 has 154 headers
# Extra headers: set()
#
# Game 664 has 154 headers
# Extra headers: set()
#
# Game 665 has 154 headers
# Extra headers: set()
#
# Game 666 has 154 headers
# Extra headers: set()
#
# Game 667 has 154 headers
# Extra headers: set()
#
# Game 668 has 154 headers
# Extra headers: set()
#
# Game 669 has 154 headers
# Extra headers: set()
#
# Game 670 has 154 headers
# Extra headers: set()
#
# Game 671 has 154 headers
# Extra headers: set()
#
# Game 672 has 154 headers
# Extra headers: set()
#
# Game 673 has 154 headers
# Extra headers: set()
#
# Game 674 has 154 headers
# Extra headers: set()
#
# Game 675 has 154 headers
# Extra headers: set()
#
# Game 676 has 154 headers
# Extra headers: set()
#
# Game 677 has 154 headers
# Extra headers: set()
#
# Game 678 has 154 headers
# Extra headers: set()
#
# Game 679 has 154 headers
# Extra headers: set()
#
# Game 680 has 154 headers
# Extra headers: set()
#
# Game 681 has 154 headers
# Extra headers: set()
#
# Game 682 has 154 headers
# Extra headers: set()
#
# Game 683 has 154 headers
# Extra headers: set()
#
# Game 684 has 154 headers
# Extra headers: set()
#
# Game 685 has 154 headers
# Extra headers: set()
#
# Game 686 has 154 headers
# Extra headers: set()
#
# Game 687 has 154 headers
# Extra headers: set()
#
# Game 688 has 154 headers
# Extra headers: set()
#
# Game 689 has 154 headers
# Extra headers: set()
#
# Game 690 has 154 headers
# Extra headers: set()
#
# Game 691 has 154 headers
# Extra headers: set()
#
# Game 692 has 154 headers
# Extra headers: set()
#
# Game 693 has 154 headers
# Extra headers: set()
#
# Game 694 has 154 headers
# Extra headers: set()
#
# Game 695 has 154 headers
# Extra headers: set()
#
# Game 696 has 154 headers
# Extra headers: set()
#
# Game 697 has 154 headers
# Extra headers: set()
#
# Game 698 has 154 headers
# Extra headers: set()
#
# Game 699 has 154 headers
# Extra headers: set()
#
# Game 700 has 154 headers
# Extra headers: set()
#
# Game 701 has 154 headers
# Extra headers: set()
#
# Game 702 has 154 headers
# Extra headers: set()
#
# Game 703 has 154 headers
# Extra headers: set()
#
# Game 704 has 154 headers
# Extra headers: set()
#
# Game 705 has 154 headers
# Extra headers: set()
#
# Game 706 has 154 headers
# Extra headers: set()
#
# Game 707 has 154 headers
# Extra headers: set()
#
# Game 708 has 154 headers
# Extra headers: set()
#
# Game 709 has 154 headers
# Extra headers: set()
#
# Game 710 has 154 headers
# Extra headers: set()
#
# Game 711 has 154 headers
# Extra headers: set()
#
# Game 712 has 154 headers
# Extra headers: set()
#
# Game 713 has 154 headers
# Extra headers: set()
#
# Game 714 has 154 headers
# Extra headers: set()
#
# Game 715 has 154 headers
# Extra headers: set()
#
# Game 716 has 154 headers
# Extra headers: set()
#
# Game 717 has 154 headers
# Extra headers: set()
#
# Game 718 has 154 headers
# Extra headers: set()
#
# Game 719 has 154 headers
# Extra headers: set()
#
# Game 720 has 154 headers
# Extra headers: set()
#
# Game 721 has 154 headers
# Extra headers: set()
#
# Game 722 has 154 headers
# Extra headers: set()
#
# Game 723 has 154 headers
# Extra headers: set()
#
# Game 724 has 154 headers
# Extra headers: set()
#
# Game 725 has 154 headers
# Extra headers: set()
#
# Game 726 has 154 headers
# Extra headers: set()
#
# Game 727 has 154 headers
# Extra headers: set()
#
# Game 728 has 154 headers
# Extra headers: set()
#
# Game 729 has 154 headers
# Extra headers: set()
#
# Game 730 has 154 headers
# Extra headers: set()
#
# Game 731 has 154 headers
# Extra headers: set()
#
# Game 732 has 154 headers
# Extra headers: set()
#
# Game 733 has 154 headers
# Extra headers: set()
#
# Game 734 has 154 headers
# Extra headers: set()
#
# Game 735 has 154 headers
# Extra headers: set()
#
# Game 736 has 154 headers
# Extra headers: set()
#
# Game 737 has 154 headers
# Extra headers: set()
#
# Game 738 has 154 headers
# Extra headers: set()
#
# Game 739 has 154 headers
# Extra headers: set()
#
# Game 740 has 154 headers
# Extra headers: set()
#
# Game 741 has 154 headers
# Extra headers: set()
#
# Game 742 has 154 headers
# Extra headers: set()
#
# Game 743 has 154 headers
# Extra headers: set()
#
# Game 744 has 154 headers
# Extra headers: set()
#
# Game 745 has 154 headers
# Extra headers: set()
#
# Game 746 has 154 headers
# Extra headers: set()
#
# Game 747 has 154 headers
# Extra headers: set()
#
# Game 748 has 154 headers
# Extra headers: set()
#
# Game 749 has 154 headers
# Extra headers: set()
#
# Game 750 has 154 headers
# Extra headers: set()
#
# Game 751 has 154 headers
# Extra headers: set()
#
# Game 752 has 154 headers
# Extra headers: set()
#
# Game 753 has 154 headers
# Extra headers: set()
#
# Game 754 has 154 headers
# Extra headers: set()
#
# Game 755 has 154 headers
# Extra headers: set()
#
# Game 756 has 154 headers
# Extra headers: set()
#
# Game 757 has 154 headers
# Extra headers: set()
#
# Game 758 has 154 headers
# Extra headers: set()
#
# Game 759 has 154 headers
# Extra headers: set()
#
# Game 760 has 154 headers
# Extra headers: set()
#
# Game 761 has 154 headers
# Extra headers: set()
#
# Game 762 has 154 headers
# Extra headers: set()
#
# Game 763 has 154 headers
# Extra headers: set()
#
# Game 764 has 154 headers
# Extra headers: set()
#
# Game 765 has 154 headers
# Extra headers: set()
#
# Game 766 has 154 headers
# Extra headers: set()
#
# Game 767 has 154 headers
# Extra headers: set()
#
# Game 768 has 154 headers
# Extra headers: set()
#
# Game 769 has 154 headers
# Extra headers: set()
#
# Game 770 has 154 headers
# Extra headers: set()
#
# Game 771 has 154 headers
# Extra headers: set()
#
# Game 772 has 154 headers
# Extra headers: set()
#
# Game 773 has 154 headers
# Extra headers: set()
#
# Game 774 has 154 headers
# Extra headers: set()
#
# Game 775 has 154 headers
# Extra headers: set()
#
# Game 776 has 154 headers
# Extra headers: set()
#
# Game 777 has 154 headers
# Extra headers: set()
#
# Game 778 has 154 headers
# Extra headers: set()
#
# Game 779 has 154 headers
# Extra headers: set()
#
# Game 780 has 154 headers
# Extra headers: set()
#
# Game 781 has 154 headers
# Extra headers: set()
#
# Game 782 has 154 headers
# Extra headers: set()
#
# Game 783 has 154 headers
# Extra headers: set()
#
# Game 784 has 154 headers
# Extra headers: set()
#
# Game 785 has 154 headers
# Extra headers: set()
#
# Game 786 has 154 headers
# Extra headers: set()
#
# Game 787 has 154 headers
# Extra headers: set()
#
# Game 788 has 154 headers
# Extra headers: set()
#
# Game 789 has 154 headers
# Extra headers: set()
#
# Game 790 has 154 headers
# Extra headers: set()
#
# Game 791 has 154 headers
# Extra headers: set()
#
# Game 792 has 154 headers
# Extra headers: set()
#
# Game 793 has 154 headers
# Extra headers: set()
#
# Game 794 has 154 headers
# Extra headers: set()
#
# Game 795 has 154 headers
# Extra headers: set()
#
# Game 796 has 154 headers
# Extra headers: set()
#
# Game 797 has 154 headers
# Extra headers: set()
#
# Game 798 has 154 headers
# Extra headers: set()
#
# Game 799 has 154 headers
# Extra headers: set()
#
# Game 800 has 154 headers
# Extra headers: set()
#
# Game 801 has 154 headers
# Extra headers: set()
#
# Game 802 has 154 headers
# Extra headers: set()
#
# Game 803 has 154 headers
# Extra headers: set()
#
# Game 804 has 154 headers
# Extra headers: set()
#
# Game 805 has 154 headers
# Extra headers: set()
#
# Game 806 has 154 headers
# Extra headers: set()
#
# Game 807 has 154 headers
# Extra headers: set()
#
# Game 808 has 154 headers
# Extra headers: set()
#
# Game 809 has 154 headers
# Extra headers: set()
#
# Game 810 has 154 headers
# Extra headers: set()
#
# Game 811 has 154 headers
# Extra headers: set()
#
# Game 812 has 154 headers
# Extra headers: set()
#
# Game 813 has 154 headers
# Extra headers: set()
#
# Game 814 has 154 headers
# Extra headers: set()
#
# Game 815 has 154 headers
# Extra headers: set()
#
# Game 816 has 154 headers
# Extra headers: set()
#
# Game 817 has 154 headers
# Extra headers: set()
#
# Game 818 has 154 headers
# Extra headers: set()
#
# Game 819 has 154 headers
# Extra headers: set()
#
# Game 820 has 154 headers
# Extra headers: set()
#
# Game 821 has 154 headers
# Extra headers: set()
#
# Game 822 has 154 headers
# Extra headers: set()
#
# Game 823 has 154 headers
# Extra headers: set()
#
# Game 824 has 154 headers
# Extra headers: set()
#
# Game 825 has 154 headers
# Extra headers: set()
#
# Game 826 has 154 headers
# Extra headers: set()
#
# Game 827 has 154 headers
# Extra headers: set()
#
# Game 828 has 154 headers
# Extra headers: set()
#
# Game 829 has 154 headers
# Extra headers: set()
#
# Game 830 has 154 headers
# Extra headers: set()
#
# Game 831 has 154 headers
# Extra headers: set()
#
# Game 832 has 154 headers
# Extra headers: set()
#
# Game 833 has 154 headers
# Extra headers: set()
#
# Game 834 has 154 headers
# Extra headers: set()
#
# Game 835 has 154 headers
# Extra headers: set()
#
# Game 836 has 154 headers
# Extra headers: set()
#
# Game 837 has 154 headers
# Extra headers: set()
#
# Game 838 has 154 headers
# Extra headers: set()
#
# Game 839 has 154 headers
# Extra headers: set()
#
# Game 840 has 154 headers
# Extra headers: set()
#
# Game 841 has 154 headers
# Extra headers: set()
#
# Game 842 has 154 headers
# Extra headers: set()
#
# Game 843 has 154 headers
# Extra headers: set()
#
# Game 844 has 154 headers
# Extra headers: set()
#
# Game 845 has 154 headers
# Extra headers: set()
#
# Game 846 has 154 headers
# Extra headers: set()
#
# Game 847 has 154 headers
# Extra headers: set()
#
# Game 848 has 154 headers
# Extra headers: set()
#
# Game 849 has 154 headers
# Extra headers: set()
#
# Game 850 has 154 headers
# Extra headers: set()
#
# Game 851 has 154 headers
# Extra headers: set()
#
# Game 852 has 154 headers
# Extra headers: set()
#
# Game 853 has 154 headers
# Extra headers: set()
#
# Game 854 has 154 headers
# Extra headers: set()
#
# Game 855 has 154 headers
# Extra headers: set()
#
# Game 856 has 154 headers
# Extra headers: set()
#
# Game 857 has 154 headers
# Extra headers: set()
#
# Game 858 has 154 headers
# Extra headers: set()
#
# Game 859 has 154 headers
# Extra headers: set()
#
# Game 860 has 154 headers
# Extra headers: set()
#
# Game 861 has 154 headers
# Extra headers: set()
#
# Game 862 has 154 headers
# Extra headers: set()
#
# Game 863 has 154 headers
# Extra headers: set()
#
# Game 864 has 154 headers
# Extra headers: set()
#
# Game 865 has 154 headers
# Extra headers: set()
#
# Game 866 has 154 headers
# Extra headers: set()
#
# Game 867 has 154 headers
# Extra headers: set()
#
# Game 868 has 154 headers
# Extra headers: set()
#
# Game 869 has 154 headers
# Extra headers: set()
#
# Game 870 has 154 headers
# Extra headers: set()
#
# Game 871 has 154 headers
# Extra headers: set()
#
# Game 872 has 154 headers
# Extra headers: set()
#
# Game 873 has 154 headers
# Extra headers: set()
#
# Game 874 has 154 headers
# Extra headers: set()
#
# Game 875 has 154 headers
# Extra headers: set()
#
# Game 876 has 154 headers
# Extra headers: set()
#
# Game 877 has 154 headers
# Extra headers: set()
#
# Game 878 has 154 headers
# Extra headers: set()
#
# Game 879 has 154 headers
# Extra headers: set()
#
# Game 880 has 154 headers
# Extra headers: set()
#
# Game 881 has 154 headers
# Extra headers: set()
#
# Game 882 has 154 headers
# Extra headers: set()
#
# Game 883 has 154 headers
# Extra headers: set()
#
# Game 884 has 154 headers
# Extra headers: set()
#
# Game 885 has 154 headers
# Extra headers: set()
#
# Game 886 has 154 headers
# Extra headers: set()
#
# Game 887 has 154 headers
# Extra headers: set()
#
# Game 888 has 154 headers
# Extra headers: set()
#
# Game 889 has 154 headers
# Extra headers: set()
#
# Game 890 has 154 headers
# Extra headers: set()
#
# Game 891 has 154 headers
# Extra headers: set()
#
# Game 892 has 154 headers
# Extra headers: set()
#
# Game 893 has 154 headers
# Extra headers: set()
#
# Game 894 has 154 headers
# Extra headers: set()
#
# Game 895 has 154 headers
# Extra headers: set()
#
# Game 896 has 154 headers
# Extra headers: set()
#
# Game 897 has 154 headers
# Extra headers: set()
#
# Game 898 has 154 headers
# Extra headers: set()
#
# Game 899 has 154 headers
# Extra headers: set()
#
# Game 900 has 154 headers
# Extra headers: set()
#
# Game 901 has 154 headers
# Extra headers: set()
#
# Game 902 has 154 headers
# Extra headers: set()
#
# Game 903 has 154 headers
# Extra headers: set()
#
# Game 904 has 154 headers
# Extra headers: set()
#
# Game 905 has 154 headers
# Extra headers: set()
#
# Game 906 has 154 headers
# Extra headers: set()
#
# Game 907 has 154 headers
# Extra headers: set()
#
# Game 908 has 154 headers
# Extra headers: set()
#
# Game 909 has 154 headers
# Extra headers: set()
#
# Game 910 has 154 headers
# Extra headers: set()
#
# Game 911 has 154 headers
# Extra headers: set()
#
# Game 912 has 154 headers
# Extra headers: set()
#
# Game 913 has 154 headers
# Extra headers: set()
#
# Game 914 has 154 headers
# Extra headers: set()
#
# Game 915 has 154 headers
# Extra headers: set()
#
# Game 916 has 154 headers
# Extra headers: set()
#
# Game 917 has 154 headers
# Extra headers: set()
#
# Game 918 has 154 headers
# Extra headers: set()
#
# Game 919 has 154 headers
# Extra headers: set()
#
# Game 920 has 154 headers
# Extra headers: set()
#
# Game 921 has 154 headers
# Extra headers: set()
#
# Game 922 has 154 headers
# Extra headers: set()
#
# Game 923 has 154 headers
# Extra headers: set()
#
# Game 924 has 154 headers
# Extra headers: set()
#
# Game 925 has 154 headers
# Extra headers: set()
#
# Game 926 has 154 headers
# Extra headers: set()
#
# Game 927 has 154 headers
# Extra headers: set()
#
# Game 928 has 154 headers
# Extra headers: set()
#
# Game 929 has 154 headers
# Extra headers: set()
#
# Game 930 has 154 headers
# Extra headers: set()
#
# Game 931 has 154 headers
# Extra headers: set()
#
# Game 932 has 154 headers
# Extra headers: set()
#
# Game 933 has 154 headers
# Extra headers: set()
#
# Game 934 has 154 headers
# Extra headers: set()
#
# Game 935 has 154 headers
# Extra headers: set()
#
# Game 936 has 154 headers
# Extra headers: set()
#
# Game 937 has 154 headers
# Extra headers: set()
#
# Game 938 has 154 headers
# Extra headers: set()
#
# Game 939 has 154 headers
# Extra headers: set()
#
# Game 940 has 154 headers
# Extra headers: set()
#
# Game 941 has 154 headers
# Extra headers: set()
#
# Game 942 has 154 headers
# Extra headers: set()
#
# Game 943 has 154 headers
# Extra headers: set()
#
# Game 944 has 154 headers
# Extra headers: set()
#
# Game 945 has 154 headers
# Extra headers: set()
#
# Game 946 has 154 headers
# Extra headers: set()
#
# Game 947 has 154 headers
# Extra headers: set()
#
# Game 948 has 154 headers
# Extra headers: set()
#
# Game 949 has 154 headers
# Extra headers: set()
#
# Game 950 has 154 headers
# Extra headers: set()
#
# Game 951 has 154 headers
# Extra headers: set()
#
# Game 952 has 154 headers
# Extra headers: set()
#
# Game 953 has 154 headers
# Extra headers: set()
#
# Game 954 has 154 headers
# Extra headers: set()
#
# Game 955 has 154 headers
# Extra headers: set()
#
# Game 956 has 154 headers
# Extra headers: set()
#
# Game 957 has 154 headers
# Extra headers: set()
#
# Game 958 has 154 headers
# Extra headers: set()
#
# Game 959 has 154 headers
# Extra headers: set()
#
# Game 960 has 154 headers
# Extra headers: set()
#
# Game 961 has 154 headers
# Extra headers: set()
#
# Game 962 has 154 headers
# Extra headers: set()
#
# Game 963 has 154 headers
# Extra headers: set()
#
# Game 964 has 154 headers
# Extra headers: set()
#
# Game 965 has 154 headers
# Extra headers: set()
#
# Game 966 has 154 headers
# Extra headers: set()
#
# Game 967 has 154 headers
# Extra headers: set()
#
# Game 968 has 154 headers
# Extra headers: set()
#
# Game 969 has 154 headers
# Extra headers: set()
#
# Game 970 has 154 headers
# Extra headers: set()
#
# Game 971 has 154 headers
# Extra headers: set()
#
# Game 972 has 154 headers
# Extra headers: set()
#
# Game 973 has 154 headers
# Extra headers: set()
#
# Game 974 has 154 headers
# Extra headers: set()
#
# Game 975 has 154 headers
# Extra headers: set()
#
# Game 976 has 154 headers
# Extra headers: set()
#
# Game 977 has 154 headers
# Extra headers: set()
#
# Game 978 has 154 headers
# Extra headers: set()
#
# Game 979 has 154 headers
# Extra headers: set()
#
# Game 980 has 154 headers
# Extra headers: set()
#
# Game 981 has 154 headers
# Extra headers: set()
#
# Game 982 has 154 headers
# Extra headers: set()
#
# Game 983 has 154 headers
# Extra headers: set()
#
# Game 984 has 154 headers
# Extra headers: set()
#
# Game 985 has 154 headers
# Extra headers: set()
#
# Game 986 has 154 headers
# Extra headers: set()
#
# Game 987 has 154 headers
# Extra headers: set()
#
# Game 988 has 154 headers
# Extra headers: set()
#
# Game 989 has 154 headers
# Extra headers: set()
#
# Game 990 has 154 headers
# Extra headers: set()
#
# Game 991 has 154 headers
# Extra headers: set()
#
# Game 992 has 154 headers
# Extra headers: set()
#
# Game 993 has 154 headers
# Extra headers: set()
#
# Game 994 has 154 headers
# Extra headers: set()
#
# Game 995 has 154 headers
# Extra headers: set()
#
# Game 996 has 154 headers
# Extra headers: set()
#
# Game 997 has 154 headers
# Extra headers: set()
#
# Game 998 has 154 headers
# Extra headers: set()
#
# Game 999 has 154 headers
# Extra headers: set()
#
# Game 1000 has 154 headers
# Extra headers: set()
#
# Game 1001 has 154 headers
# Extra headers: set()
#
# Game 1002 has 154 headers
# Extra headers: set()
#
# Game 1003 has 154 headers
# Extra headers: set()
#
# Game 1004 has 154 headers
# Extra headers: set()
#
# Game 1005 has 154 headers
# Extra headers: set()
#
# Game 1006 has 154 headers
# Extra headers: set()
#
# Game 1007 has 154 headers
# Extra headers: set()
#
# Game 1008 has 154 headers
# Extra headers: set()
#
# Game 1009 has 154 headers
# Extra headers: set()
#
# Game 1010 has 154 headers
# Extra headers: set()
#
# Game 1011 has 154 headers
# Extra headers: set()
#
# Game 1012 has 154 headers
# Extra headers: set()
#
# Game 1013 has 154 headers
# Extra headers: set()
#
# Game 1014 has 154 headers
# Extra headers: set()
#
# Game 1015 has 154 headers
# Extra headers: set()
#
# Game 1016 has 154 headers
# Extra headers: set()
#
# Game 1017 has 154 headers
# Extra headers: set()
#
# Game 1018 has 154 headers
# Extra headers: set()
#
# Game 1019 has 154 headers
# Extra headers: set()
#
# Game 1020 has 154 headers
# Extra headers: set()
#
# Game 1021 has 154 headers
# Extra headers: set()
#
# Game 1022 has 154 headers
# Extra headers: set()
#
# ...
# Extra headers: set()
#
# Game 12519 has 154 headers
# Extra headers: set()
#
# Game 12520 has 154 headers
# Extra headers: set()
#
# Game 12521 has 154 headers
# Extra headers: set()
#
# Game 12522 has 154 headers
# Extra headers: set()
#
# Game 12523 has 154 headers
# Extra headers: set()
#
# Game 12524 has 154 headers
# Extra headers: set()
#
# Game 12525 has 154 headers
# Extra headers: set()
#
# Game 12526 has 154 headers
# Extra headers: set()
#
# Game 12527 has 154 headers
# Extra headers: set()
#
# Game 12528 has 154 headers
# Extra headers: set()
#
# Game 12529 has 154 headers
# Extra headers: set()
#
# Game 12530 has 154 headers
# Extra headers: set()
#
# Game 12531 has 154 headers
# Extra headers: set()
#
# Game 12532 has 154 headers
# Extra headers: set()
#
# Game 12533 has 154 headers
# Extra headers: set()
#
# Game 12534 has 154 headers
# Extra headers: set()
#
# Game 12535 has 154 headers
# Extra headers: set()
#
# Game 12536 has 154 headers
# Extra headers: set()
#
# Game 12537 has 154 headers
# Extra headers: set()
#
# Game 12538 has 154 headers
# Extra headers: set()
#
# Game 12539 has 154 headers
# Extra headers: set()
#
# Game 12540 has 154 headers
# Extra headers: set()
#
# Game 12541 has 154 headers
# Extra headers: set()
#
# Game 12542 has 154 headers
# Extra headers: set()
#
# Game 12543 has 154 headers
# Extra headers: set()
#
# Game 12544 has 154 headers
# Extra headers: set()
#
# Game 12545 has 154 headers
# Extra headers: set()
#
# Game 12546 has 154 headers
# Extra headers: set()
#
# Game 12547 has 154 headers
# Extra headers: set()
#
# Game 12548 has 154 headers
# Extra headers: set()
#
# Game 12549 has 154 headers
# Extra headers: set()
#
# Game 12550 has 154 headers
# Extra headers: set()
#
# Game 12551 has 154 headers
# Extra headers: set()
#
# Game 12552 has 154 headers
# Extra headers: set()
#
# Game 12553 has 154 headers
# Extra headers: set()
#
# Game 12554 has 154 headers
# Extra headers: set()
#
# Game 12555 has 154 headers
# Extra headers: set()
#
# Game 12556 has 154 headers
# Extra headers: set()
#
# Game 12557 has 154 headers
# Extra headers: set()
#
# Game 12558 has 154 headers
# Extra headers: set()
#
# Game 12559 has 154 headers
# Extra headers: set()
#
# Game 12560 has 154 headers
# Extra headers: set()
#
# Game 12561 has 154 headers
# Extra headers: set()
#
# Game 12562 has 154 headers
# Extra headers: set()
#
# Game 12563 has 154 headers
# Extra headers: set()
#
# Game 12564 has 154 headers
# Extra headers: set()
#
# Game 12565 has 154 headers
# Extra headers: set()
#
# Game 12566 has 154 headers
# Extra headers: set()
#
# Game 12567 has 154 headers
# Extra headers: set()
#
# Game 12568 has 154 headers
# Extra headers: set()
#
# Game 12569 has 154 headers
# Extra headers: set()
#
# Game 12570 has 154 headers
# Extra headers: set()
#
# Game 12571 has 154 headers
# Extra headers: set()
#
# Game 12572 has 154 headers
# Extra headers: set()
#
# Game 12573 has 154 headers
# Extra headers: set()
#
# Game 12574 has 154 headers
# Extra headers: set()
#
# Game 12575 has 154 headers
# Extra headers: set()
#
# Game 12576 has 154 headers
# Extra headers: set()
#
# Game 12577 has 154 headers
# Extra headers: set()
#
# Game 12578 has 154 headers
# Extra headers: set()
#
# Game 12579 has 154 headers
# Extra headers: set()
#
# Game 12580 has 154 headers
# Extra headers: set()
#
# Game 12581 has 154 headers
# Extra headers: set()
#
# Game 12582 has 154 headers
# Extra headers: set()
#
# Game 12583 has 154 headers
# Extra headers: set()
#
# Game 12584 has 154 headers
# Extra headers: set()
#
# Game 12585 has 154 headers
# Extra headers: set()
#
# Game 12586 has 154 headers
# Extra headers: set()
#
# Game 12587 has 154 headers
# Extra headers: set()
#
# Game 12588 has 154 headers
# Extra headers: set()
#
# Game 12589 has 154 headers
# Extra headers: set()
#
# Game 12590 has 154 headers
# Extra headers: set()
#
# Game 12591 has 154 headers
# Extra headers: set()
#
# Game 12592 has 154 headers
# Extra headers: set()
#
# Game 12593 has 154 headers
# Extra headers: set()
#
# Game 12594 has 154 headers
# Extra headers: set()
#
# Game 12595 has 154 headers
# Extra headers: set()
#
# Game 12596 has 154 headers
# Extra headers: set()
#
# Game 12597 has 154 headers
# Extra headers: set()
#
# Game 12598 has 154 headers
# Extra headers: set()
#
# Game 12599 has 154 headers
# Extra headers: set()
#
# Game 12600 has 154 headers
# Extra headers: set()
#
# Game 12601 has 154 headers
# Extra headers: set()
#
# Game 12602 has 154 headers
# Extra headers: set()
#
# Game 12603 has 154 headers
# Extra headers: set()
#
# Game 12604 has 154 headers
# Extra headers: set()
#
# Game 12605 has 154 headers
# Extra headers: set()
#
# Game 12606 has 154 headers
# Extra headers: set()
#
# Game 12607 has 154 headers
# Extra headers: set()
#
# Game 12608 has 154 headers
# Extra headers: set()
#
# Game 12609 has 154 headers
# Extra headers: set()
#
# Game 12610 has 154 headers
# Extra headers: set()
#
# Game 12611 has 154 headers
# Extra headers: set()
#
# Game 12612 has 154 headers
# Extra headers: set()
#
# Game 12613 has 154 headers
# Extra headers: set()
#
# Game 12614 has 154 headers
# Extra headers: set()
#
# Game 12615 has 154 headers
# Extra headers: set()
#
# Game 12616 has 154 headers
# Extra headers: set()
#
# Game 12617 has 154 headers
# Extra headers: set()
#
# Game 12618 has 154 headers
# Extra headers: set()
#
# Game 12619 has 154 headers
# Extra headers: set()
#
# Game 12620 has 154 headers
# Extra headers: set()
#
# Game 12621 has 154 headers
# Extra headers: set()
#
# Game 12622 has 154 headers
# Extra headers: set()
#
# Game 12623 has 154 headers
# Extra headers: set()
#
# Game 12624 has 154 headers
# Extra headers: set()
#
# Game 12625 has 154 headers
# Extra headers: set()
#
# Game 12626 has 154 headers
# Extra headers: set()
#
# Game 12627 has 154 headers
# Extra headers: set()
#
# Game 12628 has 154 headers
# Extra headers: set()
#
# Game 12629 has 154 headers
# Extra headers: set()
#
# Game 12630 has 154 headers
# Extra headers: set()
#
# Game 12631 has 154 headers
# Extra headers: set()
#
# Game 12632 has 154 headers
# Extra headers: set()
#
# Game 12633 has 154 headers
# Extra headers: set()
#
# Game 12634 has 154 headers
# Extra headers: set()
#
# Game 12635 has 154 headers
# Extra headers: set()
#
# Game 12636 has 154 headers
# Extra headers: set()
#
# Game 12637 has 154 headers
# Extra headers: set()
#
# Game 12638 has 154 headers
# Extra headers: set()
#
# Game 12639 has 154 headers
# Extra headers: set()
#
# Game 12640 has 154 headers
# Extra headers: set()
#
# Game 12641 has 154 headers
# Extra headers: set()
#
# Game 12642 has 154 headers
# Extra headers: set()
#
# Game 12643 has 154 headers
# Extra headers: set()
#
# Game 12644 has 154 headers
# Extra headers: set()
#
# Game 12645 has 154 headers
# Extra headers: set()
#
# Game 12646 has 154 headers
# Extra headers: set()
#
# Game 12647 has 154 headers
# Extra headers: set()
#
# Game 12648 has 154 headers
# Extra headers: set()
#
# Game 12649 has 154 headers
# Extra headers: set()
#
# Game 12650 has 154 headers
# Extra headers: set()
#
# Game 12651 has 154 headers
# Extra headers: set()
#
# Game 12652 has 154 headers
# Extra headers: set()
#
# Game 12653 has 154 headers
# Extra headers: set()
#
# Game 12654 has 154 headers
# Extra headers: set()
#
# Game 12655 has 154 headers
# Extra headers: set()
#
# Game 12656 has 154 headers
# Extra headers: set()
#
# Game 12657 has 154 headers
# Extra headers: set()
#
# Game 12658 has 154 headers
# Extra headers: set()
#
# Game 12659 has 154 headers
# Extra headers: set()
#
# Game 12660 has 154 headers
# Extra headers: set()
#
# Game 12661 has 154 headers
# Extra headers: set()
#
# Game 12662 has 154 headers
# Extra headers: set()
#
# Game 12663 has 154 headers
# Extra headers: set()
#
# Game 12664 has 154 headers
# Extra headers: set()
#
# Game 12665 has 154 headers
# Extra headers: set()
#
# Game 12666 has 154 headers
# Extra headers: set()
#
# Game 12667 has 154 headers
# Extra headers: set()
#
# Game 12668 has 154 headers
# Extra headers: set()
#
# Game 12669 has 154 headers
# Extra headers: set()
#
# Game 12670 has 154 headers
# Extra headers: set()
#
# Game 12671 has 154 headers
# Extra headers: set()
#
# Game 12672 has 154 headers
# Extra headers: set()
#
# Game 12673 has 154 headers
# Extra headers: set()
#
# Game 12674 has 154 headers
# Extra headers: set()
#
# Game 12675 has 154 headers
# Extra headers: set()
#
# Game 12676 has 154 headers
# Extra headers: set()
#
# Game 12677 has 154 headers
# Extra headers: set()
#
# Game 12678 has 154 headers
# Extra headers: set()
#
# Game 12679 has 154 headers
# Extra headers: set()
#
# Game 12680 has 154 headers
# Extra headers: set()
#
# Game 12681 has 154 headers
# Extra headers: set()
#
# Game 12682 has 154 headers
# Extra headers: set()
#
# Game 12683 has 154 headers
# Extra headers: set()
#
# Game 12684 has 154 headers
# Extra headers: set()
#
# Game 12685 has 154 headers
# Extra headers: set()
#
# Game 12686 has 154 headers
# Extra headers: set()
#
# Game 12687 has 154 headers
# Extra headers: set()
#
# Game 12688 has 154 headers
# Extra headers: set()
#
# Game 12689 has 154 headers
# Extra headers: set()
#
# Game 12690 has 154 headers
# Extra headers: set()
#
# Game 12691 has 154 headers
# Extra headers: set()
#
# Game 12692 has 154 headers
# Extra headers: set()
#
# Game 12693 has 154 headers
# Extra headers: set()
#
# Game 12694 has 154 headers
# Extra headers: set()
#
# Game 12695 has 154 headers
# Extra headers: set()
#
# Game 12696 has 154 headers
# Extra headers: set()
#
# Game 12697 has 154 headers
# Extra headers: set()
#
# Game 12698 has 154 headers
# Extra headers: set()
#
# Game 12699 has 154 headers
# Extra headers: set()
#
# Game 12700 has 154 headers
# Extra headers: set()
#
# Game 12701 has 154 headers
# Extra headers: set()
#
# Game 12702 has 154 headers
# Extra headers: set()
#
# Game 12703 has 154 headers
# Extra headers: set()
#
# Game 12704 has 154 headers
# Extra headers: set()
#
# Game 12705 has 154 headers
# Extra headers: set()
#
# Game 12706 has 154 headers
# Extra headers: set()
#
# Game 12707 has 154 headers
# Extra headers: set()
#
# Game 12708 has 154 headers
# Extra headers: set()
#
# Game 12709 has 154 headers
# Extra headers: set()
#
# Game 12710 has 154 headers
# Extra headers: set()
#
# Game 12711 has 154 headers
# Extra headers: set()
#
# Game 12712 has 154 headers
# Extra headers: set()
#
# Game 12713 has 154 headers
# Extra headers: set()
#
# Game 12714 has 154 headers
# Extra headers: set()
#
# Game 12715 has 154 headers
# Extra headers: set()
#
# Game 12716 has 154 headers
# Extra headers: set()
#
# Game 12717 has 154 headers
# Extra headers: set()
#
# Game 12718 has 154 headers
# Extra headers: set()
#
# Game 12719 has 154 headers
# Extra headers: set()
#
# Game 12720 has 154 headers
# Extra headers: set()
#
# Game 12721 has 154 headers
# Extra headers: set()
#
# Game 12722 has 154 headers
# Extra headers: set()
#
# Game 12723 has 154 headers
# Extra headers: set()
#
# Game 12724 has 154 headers
# Extra headers: set()
#
# Game 12725 has 154 headers
# Extra headers: set()
#
# Game 12726 has 154 headers
# Extra headers: set()
#
# Game 12727 has 154 headers
# Extra headers: set()
#
# Game 12728 has 154 headers
# Extra headers: set()
#
# Game 12729 has 154 headers
# Extra headers: set()
#
# Game 12730 has 154 headers
# Extra headers: set()
#
# Game 12731 has 154 headers
# Extra headers: set()
#
# Game 12732 has 154 headers
# Extra headers: set()
#
# Game 12733 has 154 headers
# Extra headers: set()
#
# Game 12734 has 154 headers
# Extra headers: set()
#
# Game 12735 has 154 headers
# Extra headers: set()
#
# Game 12736 has 154 headers
# Extra headers: set()
#
# Game 12737 has 154 headers
# Extra headers: set()
#
# Game 12738 has 154 headers
# Extra headers: set()
#
# Game 12739 has 154 headers
# Extra headers: set()
#
# Game 12740 has 154 headers
# Extra headers: set()
#
# Game 12741 has 154 headers
# Extra headers: set()
#
# Game 12742 has 154 headers
# Extra headers: set()
#
# Game 12743 has 154 headers
# Extra headers: set()
#
# Game 12744 has 154 headers
# Extra headers: set()
#
# Game 12745 has 154 headers
# Extra headers: set()
#
# Game 12746 has 154 headers
# Extra headers: set()
#
# Game 12747 has 154 headers
# Extra headers: set()
#
# Game 12748 has 154 headers
# Extra headers: set()
#
# Game 12749 has 154 headers
# Extra headers: set()
#
# Game 12750 has 154 headers
# Extra headers: set()
#
# Game 12751 has 154 headers
# Extra headers: set()
#
# Game 12752 has 154 headers
# Extra headers: set()
#
# Game 12753 has 154 headers
# Extra headers: set()
#
# Game 12754 has 154 headers
# Extra headers: set()
#
# Game 12755 has 154 headers
# Extra headers: set()
#
# Game 12756 has 154 headers
# Extra headers: set()
#
# Game 12757 has 154 headers
# Extra headers: set()
#
# Game 12758 has 154 headers
# Extra headers: set()
#
# Game 12759 has 154 headers
# Extra headers: set()
#
# Game 12760 has 154 headers
# Extra headers: set()
#
# Game 12761 has 154 headers
# Extra headers: set()
#
# Game 12762 has 154 headers
# Extra headers: set()
#
# Game 12763 has 154 headers
# Extra headers: set()
#
# Game 12764 has 154 headers
# Extra headers: set()
#
# Game 12765 has 154 headers
# Extra headers: set()
#
# Game 12766 has 154 headers
# Extra headers: set()
#
# Game 12767 has 154 headers
# Extra headers: set()
#
# Game 12768 has 154 headers
# Extra headers: set()
#
# Game 12769 has 154 headers
# Extra headers: set()
#
# Game 12770 has 154 headers
# Extra headers: set()
#
# Game 12771 has 154 headers
# Extra headers: set()
#
# Game 12772 has 154 headers
# Extra headers: set()
#
# Game 12773 has 154 headers
# Extra headers: set()
#
# Game 12774 has 154 headers
# Extra headers: set()
#
# Game 12775 has 154 headers
# Extra headers: set()
#
# Game 12776 has 154 headers
# Extra headers: set()
#
# Game 12777 has 154 headers
# Extra headers: set()
#
# Game 12778 has 154 headers
# Extra headers: set()
#
# Game 12779 has 154 headers
# Extra headers: set()
#
# Game 12780 has 154 headers
# Extra headers: set()
#
# Game 12781 has 154 headers
# Extra headers: set()
#
# Game 12782 has 154 headers
# Extra headers: set()
#
# Game 12783 has 154 headers
# Extra headers: set()
#
# Game 12784 has 154 headers
# Extra headers: set()
#
# Game 12785 has 154 headers
# Extra headers: set()
#
# Game 12786 has 154 headers
# Extra headers: set()
#
# Game 12787 has 154 headers
# Extra headers: set()
#
# Game 12788 has 154 headers
# Extra headers: set()
#
# Game 12789 has 154 headers
# Extra headers: set()
#
# Game 12790 has 154 headers
# Extra headers: set()
#
# Game 12791 has 154 headers
# Extra headers: set()
#
# Game 12792 has 154 headers
# Extra headers: set()
#
# Game 12793 has 154 headers
# Extra headers: set()
#
# Game 12794 has 154 headers
# Extra headers: set()
#
# Game 12795 has 154 headers
# Extra headers: set()
#
# Game 12796 has 154 headers
# Extra headers: set()
#
# Game 12797 has 154 headers
# Extra headers: set()
#
# Game 12798 has 154 headers
# Extra headers: set()
#
# Game 12799 has 154 headers
# Extra headers: set()
#
# Game 12800 has 154 headers
# Extra headers: set()
#
# Game 12801 has 154 headers
# Extra headers: set()
#
# Game 12802 has 154 headers
# Extra headers: set()
#
# Game 12803 has 154 headers
# Extra headers: set()
#
# Game 12804 has 154 headers
# Extra headers: set()
#
# Game 12805 has 154 headers
# Extra headers: set()
#
# Game 12806 has 154 headers
# Extra headers: set()
#
# Game 12807 has 154 headers
# Extra headers: set()
#
# Game 12808 has 154 headers
# Extra headers: set()
#
# Game 12809 has 154 headers
# Extra headers: set()
#
# Game 12810 has 154 headers
# Extra headers: set()
#
# Game 12811 has 154 headers
# Extra headers: set()
#
# Game 12812 has 154 headers
# Extra headers: set()
#
# Game 12813 has 154 headers
# Extra headers: set()
#
# Game 12814 has 154 headers
# Extra headers: set()
#
# Game 12815 has 154 headers
# Extra headers: set()
#
# Game 12816 has 154 headers
# Extra headers: set()
#
# Game 12817 has 154 headers
# Extra headers: set()
#
# Game 12818 has 154 headers
# Extra headers: set()
#
# Game 12819 has 154 headers
# Extra headers: set()
#
# Game 12820 has 154 headers
# Extra headers: set()
#
# Game 12821 has 154 headers
# Extra headers: set()
#
# Game 12822 has 154 headers
# Extra headers: set()
#
# Game 12823 has 154 headers
# Extra headers: set()
#
# Game 12824 has 154 headers
# Extra headers: set()
#
# Game 12825 has 154 headers
# Extra headers: set()
#
# Game 12826 has 154 headers
# Extra headers: set()
#
# Game 12827 has 154 headers
# Extra headers: set()
#
# Game 12828 has 154 headers
# Extra headers: set()
#
# Game 12829 has 154 headers
# Extra headers: set()
#
# Game 12830 has 154 headers
# Extra headers: set()
#
# Game 12831 has 154 headers
# Extra headers: set()
#
# Game 12832 has 154 headers
# Extra headers: set()
#
# Game 12833 has 154 headers
# Extra headers: set()
#
# Game 12834 has 154 headers
# Extra headers: set()
#
# Game 12835 has 154 headers
# Extra headers: set()
#
# Game 12836 has 154 headers
# Extra headers: set()
#
# Game 12837 has 154 headers
# Extra headers: set()
#
# Game 12838 has 154 headers
# Extra headers: set()
#
# Game 12839 has 154 headers
# Extra headers: set()
#
# Game 12840 has 154 headers
# Extra headers: set()
#
# Game 12841 has 154 headers
# Extra headers: set()
#
# Game 12842 has 154 headers
# Extra headers: set()
#
# Game 12843 has 154 headers
# Extra headers: set()
#
# Game 12844 has 154 headers
# Extra headers: set()

# %%
games_df.head()
# Out:
#       mp     mp    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0  240.0  240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  ...
# 1  240.0  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  ...
# 2  240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 3  240.0  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  ...
# 4  240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
#
#    tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0          57.1          33.8         258.0         121.0       ATL
# 1          33.3          23.6         132.0         104.0       DET
# 2          53.2          34.6         162.0         104.0       CHI
# 3          30.4          29.0         138.0         105.0       CLE
# 4          69.4          43.7         206.0         104.0       GSW
#
#    total_opp  home_opp  season       date    won
# 0         94         1    2016 2015-10-27   True
# 1        106         0    2016 2015-10-27  False
# 2         97         1    2016 2015-10-27  False
# 3         95         0    2016 2015-10-27   True
# 4        111         1    2016 2015-10-27  False
#
# [5 rows x 154 columns]
