# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# %%
SCORE_DIR = "data/scores"

# %%
box_scores = os.listdir(SCORE_DIR)

# %%
box_scores = [os.path.join(SCORE_DIR, f) for f in box_scores if f.endswith(".html")]

# %%
def parse_html(box_score):
    with open(box_score, 'r', encoding="utf-8") as f:
        html = f.read()
        
    soup = BeautifulSoup(html)
    [s.decompose() for s in soup.select("tr.over_header")]
    [s.decompose() for s in soup.select("tr.thead")]
    return soup

# %%
def read_line_score(soup):
    line_score = pd.read_html(str(soup), attrs={"id": "line_score"})[0]
    cols = list(line_score.columns)
    cols[0] = "team"
    cols[-1] = "total"
    line_score.columns = cols
    
    line_score = line_score[["team", "total"]]
    return line_score

# %%
def read_stats(soup, team, stat):
    df = pd.read_html(str(soup), attrs={"id": f"box-{team}-game-{stat}"}, index_col=0)[0]
    df = df.apply(pd.to_numeric, errors="coerce")
    return df

# %%
def read_season_info(soup):
    nav = soup.select("#bottom_nav_container")[0]
    hrefs = [a["href"] for a in nav.find_all("a")]
    season = os.path.basename(hrefs[1]).split("_")[0]
    return season

# %%
base_cols = None
games = []

for box_score in box_scores:
    soup = parse_html(box_score)
    line_score = read_line_score(soup)
    teams = list(line_score["team"])

    summaries = []
    for team in teams:
        basic = read_stats(soup, team, "basic")
        advanced = read_stats(soup, team, "advanced")

        # pulling the last row from the basic dataframe and advanced dataframe
        # and putting them together into a single panda series
        totals = pd.concat([basic.iloc[-1,:], advanced.iloc[-1,:]])
        totals.index = totals.index.str.lower()

        maxes = pd.concat([basic.iloc[:-1,:].max(), advanced.iloc[:-1,:].max()])
        maxes.index = maxes.index.str.lower() + "_max"

        summary = pd.concat([totals,maxes])

        if base_cols is None:
            base_cols = list(summary.index.drop_duplicates(keep="first"))
            base_cols = [b for b in base_cols if "bpm" not in b]

        summary = summary[base_cols]

        summaries.append(summary)
    summary = pd.concat(summaries,axis=1).T

    game = pd.concat([summary, line_score], axis=1)

    game["home"] = [0,1]
    game_opp = game.iloc[::-1].reset_index()
    game_opp.columns += "_opp"

    full_game = pd.concat([game, game_opp], axis=1)

    full_game["season"] = read_season_info(soup)

    full_game["date"] = os.path.basename(box_score)[:8]
    full_game["date"] = pd.to_datetime(full_game["date"], format="%Y%m%d")

    full_game["won"] = full_game["total"] > full_game["total_opp"]
    games.append(full_game)
    
    if len(games) % 100 == 0:
        print(f"{len(games)} / {len(box_scores)}")
# Out:
# 100 / 2183
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:743, in _LxmlFrameParser._build_doc(self)
#     741 else:
#     742     # try to parse the input in the simplest way
# --> 743     r = parse(self.io, parser=parser)
#     744 try:
#
# File ~\anaconda3\lib\site-packages\lxml\html\__init__.py:939, in parse(filename_or_url, parser, base_url, **kw)
#     938     parser = html_parser
# --> 939 return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#
# File src/lxml/etree.pyx:3536, in lxml.etree.parse()
#
# File src/lxml/parser.pxi:1876, in lxml.etree._parseDocument()
#
# File src/lxml/parser.pxi:1902, in lxml.etree._parseDocumentFromURL()
#
# File src/lxml/parser.pxi:1805, in lxml.etree._parseDocFromFile()
#
# File src/lxml/parser.pxi:1177, in lxml.etree._BaseParser._parseDocFromFile()
#
# File src/lxml/parser.pxi:615, in lxml.etree._ParserContext._handleParseResultDoc()
#
# File src/lxml/parser.pxi:725, in lxml.etree._handleParseResult()
#
# File src/lxml/parser.pxi:652, in lxml.etree._raiseParseError()
#
# OSError: Error reading file '<html><body><h1>Los Angeles Clippers at Dallas Mavericks Box Score, November 11, 2015</h1>
# <div class="section_wrapper" id="all_other_scores">
# <div class="section_heading assoc_other_scores" id="other_scores_sh">
# <span class="section_anchor" data-label="All Games This Date" id="other_scores_link"></span><h2></h2>
# </div><div class="placeholder"></div>
# <!--     <div class="section_content" id="div_other_scores">
# 	    <div class="game_summaries compressed">
#    <h2>NBA Scores &mdash; Nov 11, 2015</h2>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="New Orleans Pelicans at Atlanta Hawks">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/NOP/2016.html">NOP</a></td>
# 			<td class="right">98</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/201511110ATL.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/ATL/2016.html">ATL</a></td>
# 			<td class="right">106</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Indiana Pacers at Boston Celtics">
# 		<tbody>
# 		<tr class="winner">
# 			<td><a href="/teams/IND/2016.html">IND</a></td>
# 			<td class="right">102</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/201511110BOS.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="loser">
# 			<td><a href="/teams/BOS/2016.html">BOS</a></td>
# 			<td class="right">91</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="New York Knicks at Charlotte Hornets">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/NYK/2016.html">NYK</a></td>
# 			<td class="right">93</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/201511110CHO.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/CHO/2016.html">CHO</a></td>
# 			<td class="right">95</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover current ">
# 	<table class="teams poptip" data-tip="Los Angeles Clippers at Dallas Mavericks">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/LAC/2016.html">LAC</a></td>
# 			<td class="right">108</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/201511110DAL.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/DAL/2016.html">DAL</a></td>
# 			<td class="right">118</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Milwaukee Bucks at Denver Nuggets">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/MIL/2016.html">MIL</a></td>
# 			<td class="right">102</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/201511110DEN.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/DEN/2016.html">DEN</a></td>
# 			<td class="right">103</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Brooklyn Nets at Houston Rockets">
# 		<tbody>
# 		<tr class="winner">
# 			<td><a href="/teams/BRK/2016.html">BRK</a></td>
# 			<td class="right">106</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/201511110HOU.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="loser">
# 			<td><a href="/teams/HOU/2016.html">HOU</a></td>
# 			<td class="right">98</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Golden State Warriors at Memphis Grizzlies">
# 		<tbody>
# 		<tr class="winner">
# 			<td><a href="/teams/GSW/2016.html">GSW</a></td>
# 			<td class="right">100</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/201511110MEM.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="loser">
# 			<td><a href="/teams/MEM/2016.html">MEM</a></td>
# 			<td class="right">84</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Los Angeles Lakers at Orlando Magic">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/LAL/2016.html">LAL</a></td>
# 			<td class="right">99</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/201511110ORL.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/ORL/2016.html">ORL</a></td>
# 			<td class="right">101</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Toronto Raptors at Philadelphia 76ers">
# 		<tbody>
# 		<tr class="winner">
# 			<td><a href="/teams/TOR/2016.html">TOR</a></td>
# 			<td class="right">119</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/
html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="loser">
# <td><a href="/teams/POR/2016.html">POR</a></td>
# <td class="right">101</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="game_summary nohover">
# <table class="teams poptip" data-tip="Detroit Pistons at Sacramento Kings">
# <tbody>
# <tr class="loser">
# <td><a href="/teams/DET/2016.html">DET</a></td>
# <td class="right">92</td>
# <td class="right gamelink">
# <a href="/boxscores/201511110SAC.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="winner">
# <td><a href="/teams/SAC/2016.html">SAC</a></td>
# <td class="right">101</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="scorebox">
# <div>
# <div>
# <div class="media-item logo">
# <img alt="2016 Los Angeles Clippers Logo" class="teamlogo" src="https://cdn.ssref.net/req/202509031/tlogo/bbr/LAC-2016.png"/>
# <p><a href="http://www.sportslogos.net/">via Sports Logos.net</a></p>
# <p><a href="https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">About logos</a></p>
# </div>
# <strong>
# <a href="/teams/LAC/2016.html">Los Angeles Clippers</a>
# </strong>
# </div>
# <div class="scores">
# <div class="score">108</div>
# </div><div>5-3</div>
# <div class="prevnext">
# <a class="button2 prev" href="/boxscores/201511090LAC.html">Prev Game</a>
# <a class="button2 next" href="/boxscores/201511120PHO.html">Next Game</a>
# </div>
# </div>
# <div>
# <div>
# <div class="media-item logo loader">
# <img alt="2016 Dallas Mavericks Logo" class="teamlogo" src="https://cdn.ssref.net/req/202509031/tlogo/bbr/DAL-2016.png"/>
# <p><a href="http://www.sportslogos.net/">via Sports Logos.net</a></p>
# <p><a href="https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">About logos</a></p>
# </div>
# <strong>
# <a href="/teams/DAL/2016.html">Dallas Mavericks</a>
# </strong>
# </div>
# <div class="scores">
# <div class="score">118</div>
# </div><div>4-4</div>
# <div class="prevnext">
# <a class="button2 prev" href="/boxscores/201511100NOP.html">Prev Game</a>
# <a class="button2 next" href="/boxscores/201511130DAL.html">Next Game</a>
# </div>
# </div>
# <div class="scorebox_meta">
# <div>8:00 PM, November 11, 2015</div><div>American Airlines Center, Dallas, Texas</div>
# <div><em>Logos <a href="http://www.sportslogos.net/">via Sports Logos.net</a>
#             / <a href="//www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">About logos</a></em></div>
# </div>
# </div>
# <style>
# .fb .scorebox { position: relative; max-width: 640px; }
# .fb .scorebox > div:first-child .scores > div:after { position: absolute; left: 0; content: ':'; width: 100%; }
# .fb .scorebox .scorebox_meta { margin-top: 10px; }
# .fb .scorebox .score { font-size: 1.9em; font-weight: 800; }
# .fb .scorebox .score_pen, .fb .scorebox .score_aggr, .fb .scorebox .score_xg { font-size: 1.28em; font-weight: bold; margin-top: 12px; }
# .fb .scorebox > div:first-child .score_pen:before, .fb .scorebox > div:first-child .score_aggr:before, .fb .scorebox > div:first-child .score_xg:before {
# 	position: absolute;
# 	width: 100%;
# 	left: 0;
# 	margin-top: -11px;
# 	color: #777;
# 	font-size: 13px;
# 	font-weight: bold;
# }
# .fb .scorebox > div:first-child .score_pen:before  { content: 'Penalties'; }
# .fb .scorebox > div:first-child .score_aggr:before { content: 'Aggregate'; }
# .fb .scorebox > div:first-child .score_xg:before { content: 'xG'; }
#
# @media screen and (min-width: 470px) {
# 	.fb .scorebox .prevnext { min-width: 200px; }
# }
#
# @media screen and (min-width: 800px) {
# 	.fb .scorebox                   .scores  { position: absolute; top: 35px; left: 0; }
# 	.fb .scorebox > div:first-child .scores  { left: auto; right: 0; }
#
# 	.fb .scorebox .scores > div       { padding: 0 10px; }
# 	.fb .scorebox > div:first-child .scores > div:after { width: 200%; }
#
# 	.fb .scorebox .score { font-size: 2.7em; }
#
# 	.fb .scorebox .score_pen, .fb .scorebox .score_aggr, .fb .scorebox .score_xg { margin-top: 17px; }
#
# 	.fb .scorebox > div:first-child .score_pen:before, .fb .scorebox > div:first-child .score_aggr:before, .fb .scorebox > div:first-child .score_xg:before { width: 200%; margin-top: -15px; }
#
# 	.fb .scorebox > div { padding: 0 8%; position: relative; }
# 	.fb .scorebox .event { position: absolute; padding: 0; top: 15px; right: -160px; text-align: left; }
# 	.fb .scorebox .event#a { text-align: right; left: -160px; right: auto; }
# 	.fb .scorebox .event > div { margin-bottom: 6px; }
# }
#
# @media screen and (max-width: 1020px) {
# 	.fb .scorebox .event { display: none; }
# }
# </style>
# <!-- fs_btf_3 -->
# <div class="adblock">
# <!-- div#fs_fs_btf_3  -->
# <div align="center" data-freestar-ad="__300x250 __970x90" id="div-gpt-ad-728x90-BTF-3">
# <script data-cfasync="false" type="text/javascript">
#     if (sr_detect_ie || sr_detect_edge || Modernizr.adfree) {
#     }
#     else {
#         console.log('push ad:div-gpt-ad-728x90-BTF-3');
#         freestar.config.enabled_slots.push({ placementName: "div-gpt-ad-728x90-BTF-3", slotId: "div-gpt-ad-728x90-BTF-3" });
#     }
#   </script>
# </div>
# <!-- /div.#fs_fs_btf_3 -->
# </div>
# <div class="filter">
# <div class="current">
# <a href="/boxscores/201511110DAL.html">Box Score</a>
# </div><div class="">
# <a href="/boxscores/pbp/201511110DAL.html">Play-By-Play</a>
# </div><div class="">
# <a href="/boxscores/shot-chart/201511110DAL.html">Shot Charts</a>
# </div><div class="">
# <a href="/boxscores/plus-minus/201511110DAL.html">Plus/Minus</a>
# </div></div>
# <div class="callout light new_stathead_player_highlight stathead_event">
# <div class="callout_logos">
# <a class="sh-cta-button" href="
#
# https://stathead.com/sport/basketball/?&amp;utm_medium=sr_xsite&amp;utm_source=bbr&amp;utm_campaign=2023_03_bnnr_boxes_stathead&amp;utm_content=img_logo" rel="noopener" target="_blank">
# <img alt="Stathead Logo" onerror="this.src='https://cdn.ssref.net/req/202004233/logos/bbr-logo-white.png'; this.onerror = null;" src="https://cdn.ssref.net/req/202004233/logos/stathead-bbr-white.svg"/>
# </a>
# <div id="powered_by">POWERED BY</div>
# <a class="sh-cta-button" href="
#
# https://stathead.com/sport/basketball/?&amp;utm_medium=sr_xsite&amp;utm_source=bbr&amp;utm_campaign=2023_03_bnnr_boxes_stathead&amp;utm_content=img_logo" rel="noopener" target="_blank">
# <img alt=".com Logo" onerror="this.src='https://cdn.ssref.net/req/202004233/logos/bbr-logo-white.png'; this.onerror = null;" src="https://cdn.ssref.net/req/202004233/logos/bbr-logo-white.svg"/>
# </a>
# </div>
# <div class="new_stathead_player_highlight_content">
# <div><b>Looking for something amazing? Uncover the story that stats can tell with Stathead.</b></div>
# <div class="cta">Search through thousands of plays from basketball history using the Event Finder.</div>
# <div>
# <a class="button" href="
#
# https://stathead.com/sport/basketball/?&amp;utm_medium=sr_xsite&amp;utm_source=bbr&amp;utm_campaign=2023_03_bnnr_boxes_stathead&amp;utm_content=bttn_cta" rel="noopener" target="_blank">Try it &amp; get your first month FREE</a>
# </div>
# </div>
# </div>
# <div class="content_grid">
# <div>
# <div class="table_wrapper" id="all_line_score">
# <div class="section_heading assoc_line_score" id="line_score_sh">
# <span class="section_anchor" data-label="Line Score" id="line_score_link"></span><h2>Line Score</h2>
# <div class="section_heading_text">
# <ul>
# </ul>
# </div>
# </div><div class="placeholder"></div>
# <!--
#
# <div class="table_container" id="div_line_score">
#
#     <table class="suppress_all stats_table" id="line_score" data-cols-to-freeze="0">
#     <caption>Line Score Table</caption>
#
#
#    <colgroup><col><col><col><col><col><col></colgroup>
#    <thead>
#
#
#       <tr class="over_header">
#          <th aria-label="" data-stat="header_tmp" colspan="6" class=" over_header center" >Scoring</th>
#       </tr>
#
#       <tr>
#          <th aria-label="&nbsp;" data-stat="team" scope="col" class=" poptip center" data-over-header="Scoring" >&nbsp;</th>
#          <th aria-label="1" data-stat="1" scope="col" class=" poptip center" data-over-header="Scoring" >1</th>
#          <th aria-label="2" data-stat="2" scope="col" class=" poptip center" data-over-header="Scoring" >2</th>
#          <th aria-label="3" data-stat="3" scope="col" class=" poptip center" data-over-header="Scoring" >3</th>
#          <th aria-label="4" data-stat="4" scope="col" class=" poptip center" data-over-header="Scoring" >4</th>
#          <th aria-label="T" data-stat="T" scope="col" class=" poptip center" data-over-header="Scoring" >T</th>
#       </tr>
#       </thead>
# <tbody><tr ><th scope="row" class="center " data-stat="team" ><a href='/teams/LAC/2016.html'>LAC</a></th><td class="center " data-stat="1" >35</td><td class="center " data-stat="2" >19</td><td class="center " data-stat="3" >24</td><td class="center " data-stat="4" >30</td><td class="center " data-stat="T" ><strong>108</strong></td></tr>
# <tr ><th scope="row" class="center " data-stat="team" ><a href='/teams/DAL/2016.html'>DAL</a></th><td class="center " data-stat="1" >27</td><td class="center " data-stat="2" >26</td><td class="center " data-stat="3" >31</td><td class="center " data-stat="4" >34</td><td class="center " data-stat="T" ><strong>118</strong></td></tr>
#
# </table>
#
#
# </div>
# -->
# <div class="table_container is_setup" id="div_line_score">
# <table class="suppress_all stats_table" data-cols-to-freeze="0" id="line_score">
# <caption>Line Score Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
#
# <tr>
# <th aria-label=" " class="poptip center" data-over-header="Scoring" data-stat="team" scope="col"> </th>
# <th aria-label="1" class="poptip center" data-over-header="Scoring" data-stat="1" scope="col">1</th>
# <th aria-label="2" class="poptip center" data-over-header="Scoring" data-stat="2" scope="col">2</th>
# <th aria-label="3" class="poptip center" data-over-header="Scoring" data-stat="3" scope="col">3</th>
# <th aria-label="4" class="poptip center" data-over-header="Scoring" data-stat="4" scope="col">4</th>
# <th aria-label="T" class="poptip center" data-over-header="Scoring" data-stat="T" scope="col">T</th>
# </tr>
# </thead>
# <tbody><tr><th class="center" data-stat="team" scope="row"><a href="/teams/LAC/2016.html">LAC</a></th><td class="center" data-stat="1">35</td><td class="center" data-stat="2">19</td><td class="center" data-stat="3">24</td><td class="center" data-stat="4">30</td><td class="center" data-stat="T"><strong>108</strong></td></tr>
# <tr><th class="center" data-stat="team" scope="row"><a href="/teams/DAL/2016.html">DAL</a></th><td class="center" data-stat="1">27</td><td class="center" data-stat="2">26</td><td class="center" data-stat="3">31</td><td class="center" data-stat="4">34</td><td class="center" data-stat="T"><strong>118</strong></td></tr>
# </tbody></table>
# </div>
# </div>
# </div><div>
# <div class="table_wrapper" id="all_four_factors">
# <div class="section_heading assoc_four_factors" id="four_factors_sh">
# <span class="section_anchor" data-label="Four Factors" id="four_factors_link"></span><h2>Four Factors</h2>
# <div class="section_heading_text">
# <ul>
# </ul>
# </div>
# </div><div class="placeholder"></div>
# <!--
#
# <div class="table_container" id="div_four_factors">
#
#     <table class="suppress_all stats_table" id="four_factors" data-cols-to-freeze=",1">
#     <caption>Four Factors Table</caption>
#
#
#    <colgroup><col><col><col><col><col><col><col></colgroup>
#    <thead>
#
#
#       <tr class="over_header">
#          <th aria-label="" data-stat="" colspan="2" class=" over_header center" ></th>
#          <th aria-label="" data-stat="header_tmp" colspan="4" class=" over_header center" >Four Factors</th><th></th>
#       </tr>
#
#       <tr>
#          <th aria-label="&nbsp;" data-stat="team_id" scope="col" class=" poptip sort_default_asc left" data-tip="Team" >&nbsp;</th>
#          <th aria-label="Pace Factor" data-stat="pace" scope="col" class=" poptip right" data-tip="<b>Pace Factor</b>: An estimate of possessions per 48 minutes" >Pace</th>
#          <th aria-label="Effective Field Goal Percentage" data-stat="efg_pct" scope="col" class=" poptip right" data-tip="<strong>Effective Field Goal Percentage</strong><br>This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal." data-over-header="Four Factors" >eFG%</th>
#          <th aria-label="Turnover Percentage" data-stat="tov_pct" scope="col" class=" poptip sort_default_asc right" data-tip="<b>Turnover Percentage</b><br>An estimate of turnovers committed per 100 plays." data-over-header="Four Factors" >TOV%</th>
#          <th aria-label="Offensive Rebound Percentage" data-stat="orb_pct" scope="col" class=" poptip right" data-tip="<b>Offensive Rebound Percentage</b><br>An estimate of the percentage of available offensive rebounds a player grabbed while they were on the floor." data-over-header="Four Factors" >ORB%</th>
#          <th aria-label="FT/FGA" data-stat="ft_rate" scope="col" class=" poptip right" data-tip="Free Throws Per Field Goal Attempt" data-over-header="Four Factors" >FT/FGA</th>
#          <th aria-label="Offensive Rating" data-stat="off_rtg" scope="col" class=" poptip right" data-tip="<b>Offensive Rating</b><br>An estimate of points produced (players) or scored (teams) per 100 possessions" >ORtg</th>
#       </tr>
#       </thead>
# <tbody><tr ><th scope="row" class="left " data-stat="team_id" ><a href="/teams/LAC/2016.html">LAC</a></th><td class="right " data-stat="pace" >94.6</td><td class="right minus" data-stat="efg_pct" >.500</td><td class="right plus" data-stat="tov_pct" >9.0</td><td class="right plus" data-stat="orb_pct" >26.5</td><td class="right minus" data-stat="ft_rate" >.256</td><td class="right " data-stat="off_rtg" >114.2</td></tr>
# <tr ><th scope="row" class="left " data-stat="team_id" ><a href="/teams/DAL/2016.html">DAL</a></th><td class="right " data-stat="pace" >94.6</td><td class="right plus" data-stat="efg_pct" >.625</td><td class="right minus" data-stat="tov_pct" >13.6</td><td class="right minus" data-stat="orb_pct" >22.2</td><td class="right plus" data-stat="ft_rate" >.303</td><td class="right " data-stat="off_rtg" >124.7</td></tr>
#
# </table>
#
#
# </div>
# -->
# <div class="table_container is_setup" id="div_four_factors">
# <table class="suppress_all stats_table" data-cols-to-freeze=",1" id="four_factors">
# <caption>Four Factors Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
#
# <tr>
# <th aria-label=" " class="poptip sort_default_asc left" data-stat="team_id" data-tip="Team" scope="col"> </th>
# <th aria-label="Pace Factor" class="poptip right" data-stat="pace" data-tip="&lt;b&gt;Pace Factor&lt;/b&gt;: An estimate of possessions per 48 minutes" scope="col">Pace</th>
# <th aria-label="Effective Field Goal Percentage" class="poptip right" data-over-header="Four Factors" data-stat="efg_pct" data-tip="&lt;strong&gt;Effective Field Goal Percentage&lt;/strong&gt;&lt;br&gt;This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal." scope="col">eFG%</th>
# <th aria-label="Turnover Percentage" class="poptip sort_default_asc right" data-over-header="Four Factors" data-stat="tov_pct" data-tip="&lt;b&gt;Turnover Percentage&lt;/b&gt;&lt;br&gt;An estimate of turnovers committed per 100 plays." scope="col">TOV%</th>
# <th aria-label="Offensive Rebound Percentage" class="poptip right" data-over-header="Four Factors" data-stat="orb_pct" data-tip="&lt;b&gt;Offensive Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available offensive rebounds a player grabbed while they were on the floor." scope="col">ORB%</th>
# <th aria-label="FT/FGA" class="poptip right" data-over-header="Four Factors" data-stat="ft_rate" data-tip="Free Throws Per Field Goal Attempt" scope="col">FT/FGA</th>
# <th aria-label="Offensive Rating" class="poptip right" data-stat="off_rtg" data-tip="&lt;b&gt;Offensive Rating&lt;/b&gt;&lt;br&gt;An estimate of points produced (players) or scored (teams) per 100 possessions" scope="col">ORtg</th>
# </tr>
# </thead>
# <tbody><tr><th class="left" data-stat="team_id" scope="row"><a href="/teams/LAC/2016.html">LAC</a></th><td class="right" data-stat="pace">94.6</td><td class="right minus" data-stat="efg_pct">.500</td><td class="right plus" data-stat="tov_pct">9.0</td><td class="right plus" data-stat="orb_pct">26.5</td><td class="right minus" data-stat="ft_rate">.256</td><td class="right" data-stat="off_rtg">114.2</td></tr>
# <tr><th class="left" data-stat="team_id" scope="row"><a href="/teams/DAL/2016.html">DAL</a></th><td class="right" data-stat="pace">94.6</td><td class="right plus" data-stat="efg_pct">.625</td><td class="right minus" data-stat="tov_pct">13.6</td><td class="right minus" data-stat="orb_pct">22.2</td><td class="right plus" data-stat="ft_rate">.303</td><td class="right" data-stat="off_rtg">124.7</td></tr>
# </tbody></table>
# </div>
# </div>
# </div>
# </div>
# <div class="filter switcher"><div class="current" onclick="sr_st_construct_stats_table_features('box-LAC-game-basic', 0); sr_st_construct_stats_table_features('box-DAL-game-basic', 0);"><a class="sr_preset" data-hide=".box-LAC,.box-DAL" data-show=".box-LAC-game,.box-DAL-game" href="javascript:void(0)">Game</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-LAC-q1-basic', 0); sr_st_construct_stats_table_features('box-DAL-q1-basic', 0);"><a class="sr_preset" data-hide=".box-LAC,.box-DAL" data-show=".box-LAC-q1,.box-DAL-q1" href="javascript:void(0)">Q1</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-LAC-q2-basic', 0); sr_st_construct_stats_table_features('box-DAL-q2-basic', 0);"><a class="sr_preset" data-hide=".box-LAC,.box-DAL" data-show=".box-LAC-q2,.box-DAL-q2" href="javascript:void(0)">Q2</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-LAC-h1-basic', 0); sr_st_construct_stats_table_features('box-DAL-h1-basic', 0);"><a class="sr_preset" data-hide=".box-LAC,.box-DAL" data-show=".box-LAC-h1,.box-DAL-h1" href="javascript:void(0)">H1</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-LAC-q3-basic', 0); sr_st_construct_stats_table_features('box-DAL-q3-basic', 0);"><a class="sr_preset" data-hide=".box-LAC,.box-DAL" data-show=".box-LAC-q3,.box-DAL-q3" href="javascript:void(0)">Q3</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-LAC-q4-basic', 0); sr_st_construct_stats_table_features('box-DAL-q4-basic', 0);"><a class="sr_preset" data-hide=".box-LAC,.box-DAL" data-show=".box-LAC-q4,.box-DAL-q4" href="javascript:void(0)">Q4</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-LAC-h2-basic', 0); sr_st_construct_stats_table_features('box-DAL-h2-basic', 0);"><a class="sr_preset" data-hide=".box-LAC,.box-DAL" data-show=".box-LAC-h2,.box-DAL-h2" href="javascript:void(0)">H2</a></div></div><div class="section_wrapper box-LAC box-LAC-game" id="all_box-LAC-game-basic"> <div class="section_content is_setup" id="div_box-LAC-game-basic">
# <div class="table_wrapper" id="all_box-LAC-game-basic">
# <div class="section_heading assoc_box-LAC-game-basic has_controls" id="box-LAC-game-basic_sh">
# <span class="section_anchor" data-label="Los Angeles Clippers Basic and Advanced Stats" id="box-LAC-game-basic_link"></span><h2>Los Angeles Clippers Basic and Advanced Stats</h2>
# <div class="section_heading_text">
# <ul>
# <li class="hasmore"><span>Share &amp; Export</span><div><ul><li><button class="tooltip" id="share_on_box-LAC-game-basic" tip="Use a customizable report creator that can&lt;br&gt;output HTML, CSV, or a shareable link." type="button">Modify, Export &amp; Share Table</button></li><li><button class="tooltip" tip="Export table as &lt;br&gt;suitable for use with Excel" type="button">Get as Excel Workbook</button><a id="dlink" style="display: none;"></a></li><li><button class="tooltip" tip="Convert the table below to comma-separated values&lt;br&gt;suitable for use with Excel" type="button">Get table as CSV (for Excel)</button></li><li><button class="tooltip" href="#box-LAC-game-basic" id="a_box-LAC-game-basic" name="box-LAC-game-basic" tip="Get a link directly to this table on this page" type="button">Get Link to Table</button></li><li><button class="tooltip" tip="" type="button">About Sharing Tools</button></li><li><button class="tooltip" tip="" type="button"><a href="https://www.youtube.com/watch?v=MWapXbaWs_U&amp;feature=youtu.be" target="_blank">Video: SR Sharing Tools &amp; How-to</a></button></li><li><button class="tooltip" tip="" type="button"><a href="https://www.youtube.com/watch?v=JkDLV0roT14&amp;feature=youtu.be" target="_blank">Video: Stats Table Tips &amp; Tricks</a></button></li><li><button class="tooltip" tip="" type="button"><a href="https://www.sports-reference.com/data_use.html" target="_blank">Data Usage Terms</a></button></li></ul></div></li><li><button class="tooltip" tip="Show a glossary for each term in the table below&lt;br&gt;or hold your mouse over the header" type="button">Glossary</button></li></ul>
# </div>
# </div>
# <div class="table_container" id="div_box-LAC-game-basic">
# <table class="sortable stats_table now_sortable" data-cols-to-freeze=",1" id="box-LAC-game-basic">
# <caption>Los Angeles Clippers Basic and Advanced Stats Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
#
# <tr>
# <th aria-label="Starters" class="poptip sort_default_asc center" data-stat="player" scope="col">Starters</th>
# <th aria-label="Minutes Played" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="mp" data-tip="Minutes Played" scope="col">MP</th>
# <th aria-label="Field Goals" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg" data-tip="Field Goals" scope="col">FG</th>
# <th aria-label="FGA" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fga" data-tip="Field Goal Attempts" scope="col">FGA</th>
# <th aria-label="Field Goal Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">FG%</th>
# <th aria-label="3-Point Field Goals" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3" data-tip="3-Point Field Goals" scope="col">3P</th>
# <th aria-label="3-Point Field Goal Attempts" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3a" data-tip="3-Point Field Goal Attempts" scope="col">3PA</th>
# <th aria-label="3-Point Field Goal Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage" scope="col">3P%</th>
# <th aria-label="Free Throws" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="ft" data-tip="Free Throws" scope="col">FT</th>
# <th aria-label="Free Throw Attempts" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fta" data-tip="Free Throw Attempts" scope="col">FTA</th>
# <th aria-label="Free Throw Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="ft_pct" data-tip="Free Throw Percentage" scope="col">FT%</th>
# <th aria-label="Offensive Rebounds" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="orb" data-tip="Offensive Rebounds" scope="col">ORB</th>
# <th aria-label="Defensive Rebounds" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="drb" data-tip="Defensive Rebounds" scope="col">DRB</th>
# <th aria-label="Total Rebounds" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="trb" data-tip="Total Rebounds" scope="col">TRB</th>
# <th aria-label="Assists" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="ast" data-tip="Assists" scope="col">AST</th>
# <th aria-label="Steals" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="stl" data-tip="Steals" scope="col">STL</th>
# <th aria-label="Blocks" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="blk" data-tip="Blocks" scope="col">BLK</th>
# <th aria-label="Turnovers" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="tov" data-tip="Turnovers" scope="col">TOV</th>
# <th aria-label="Personal Fouls" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="pf" data-tip="Personal Fouls" scope="col">PF</th>
# <th aria-label="Points" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="pts" data-tip="Points" scope="col">PTS</th>
# <th aria-label="GmSc" class="poptip right" data-over-header="Basic Box Score Stats" data-stat="game_score" data-tip="Game Score" scope="col">GmSc</th>
# <th aria-label="Plus/Minus" class="poptip right" data-over-header="Basic Box Score Stats" data-stat="plus_minus" data-tip="Plus/Minus" scope="col">+/-</th>
# </tr>
# </thead>
td><td class="right poptip" data-stat="bpm" data-tip="OBPM: -3.3&lt;br&gt; DBPM: -0.2&lt;br&gt; VORP: -0.8&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-3.5</td></tr>
# <tr data-row="7"><th class="left" csk="Powell,Dwight" data-append-csv="poweldw01" data-stat="player" scope="row"><a href="/players/p/poweldw01.html">Dwight Powell</a></th><td class="right" csk="978" data-stat="mp">16:18</td><td class="right" data-stat="ts_pct">.800</td><td class="right" data-stat="efg_pct">.800</td><td class="right iz" data-stat="fg3a_per_fga_pct">.000</td><td class="right iz" data-stat="fta_per_fga_pct">.000</td><td class="right" data-stat="orb_pct">24.5</td><td class="right" data-stat="drb_pct">18.0</td><td class="right" data-stat="trb_pct">20.8</td><td class="right" data-stat="ast_pct">9.7</td><td class="right iz" data-stat="stl_pct">0.0</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right" data-stat="tov_pct">16.7</td><td class="right" data-stat="usg_pct">17.3</td><td class="right" data-stat="off_rtg">148</td><td class="right" data-stat="def_rtg">117</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: 2.3&lt;br&gt; DBPM: -1.8&lt;br&gt; VORP: 0.9&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">0.5</td></tr>
# <tr data-row="8"><th class="left" csk="Barea,J.J." data-append-csv="bareajo01" data-stat="player" scope="row"><a href="/players/b/bareajo01.html">J.J. Barea</a></th><td class="right" csk="938" data-stat="mp">15:38</td><td class="right iz" data-stat="ts_pct">.000</td><td class="right iz" data-stat="efg_pct">.000</td><td class="right iz" data-stat="fg3a_per_fga_pct">.000</td><td class="right" data-stat="fta_per_fga_pct">.400</td><td class="right iz" data-stat="orb_pct">0.0</td><td class="right" data-stat="drb_pct">6.3</td><td class="right" data-stat="trb_pct">3.6</td><td class="right" data-stat="ast_pct">51.2</td><td class="right iz" data-stat="stl_pct">0.0</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right" data-stat="tov_pct">25.4</td><td class="right" data-stat="usg_pct">23.7</td><td class="right" data-stat="off_rtg">56</td><td class="right" data-stat="def_rtg">122</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: -8.9&lt;br&gt; DBPM: -8.9&lt;br&gt; VORP: -5.1&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-17.8</td></tr>
# <tr data-row="9"><th class="left" csk="Villanueva,Charlie" data-append-csv="villach01" data-stat="player" scope="row"><a href="/players/v/villach01.html">Charlie Villanueva</a></th><td class="right" csk="723" data-stat="mp">12:03</td><td class="right" data-stat="ts_pct">.500</td><td class="right" data-stat="efg_pct">.500</td><td class="right" data-stat="fg3a_per_fga_pct">.500</td><td class="right iz" data-stat="fta_per_fga_pct">.000</td><td class="right iz" data-stat="orb_pct">0.0</td><td class="right" data-stat="drb_pct">24.4</td><td class="right" data-stat="trb_pct">14.1</td><td class="right" data-stat="ast_pct">11.7</td><td class="right iz" data-stat="stl_pct">0.0</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right iz" data-stat="tov_pct">0.0</td><td class="right" data-stat="usg_pct">15.6</td><td class="right" data-stat="off_rtg">113</td><td class="right" data-stat="def_rtg">116</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: 1.1&lt;br&gt; DBPM: -1.7&lt;br&gt; VORP: 0.4&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-0.5</td></tr>
# <tr data-row="10"><th class="left" csk="Anderson,Justin" data-append-csv="anderju01" data-stat="player" scope="row"><a href="/players/a/anderju01.html">Justin Anderson</a></th><td class="right" csk="624" data-stat="mp">10:24</td><td class="right" data-stat="ts_pct">1.167</td><td class="right" data-stat="efg_pct">1.167</td><td class="right" data-stat="fg3a_per_fga_pct">.333</td><td class="right iz" data-stat="fta_per_fga_pct">.000</td><td class="right iz" data-stat="orb_pct">0.0</td><td class="right" data-stat="drb_pct">18.8</td><td class="right" data-stat="trb_pct">10.9</td><td class="right iz" data-stat="ast_pct">0.0</td><td class="right" data-stat="stl_pct">4.9</td><td class="right" data-stat="blk_pct">7.8</td><td class="right iz" data-stat="tov_pct">0.0</td><td class="right" data-stat="usg_pct">13.5</td><td class="right" data-stat="off_rtg">233</td><td class="right" data-stat="def_rtg">101</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: 13.5&lt;br&gt; DBPM: 8.2&lt;br&gt; VORP: 5.1&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">21.7</td></tr>
# <tr data-row="11"><th class="left" csk="Evans,Jeremy" data-append-csv="evansje01" data-stat="player" scope="row"><a href="/players/e/evansje01.html">Jeremy Evans</a></th><td class="right" csk="45" data-stat="mp">0:45</td><td class="right iz" data-stat="ts_pct"></td><td class="right iz" data-stat="efg_pct"></td><td class="right iz" data-stat="fg3a_per_fga_pct"></td><td class="right iz" data-stat="fta_per_fga_pct"></td><td class="right iz" data-stat="orb_pct">0.0</td><td class="right" data-stat="drb_pct">100.0</td><td class="right" data-stat="trb_pct">75.3</td><td class="right iz" data-stat="ast_pct">0.0</td><td class="right iz" data-stat="stl_pct">0.0</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right" data-stat="tov_pct">100.0</td><td class="right" data-stat="usg_pct">62.6</td><td class="right iz" data-stat="off_rtg">0</td><td class="right" data-stat="def_rtg">77</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: -53.1&lt;br&gt; DBPM: -4.7&lt;br&gt; VORP: -0.9&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-57.8</td></tr>
# <tr data-row="12"><th class="left" csk="Mejri,Salah" data-append-csv="mejrisa01" data-stat="player" scope="row"><a href="/players/m/mejrisa01.html">Salah Mejri</a></th><td class="right" csk="0" data-stat="mp">0:00</td><td class="right iz" data-stat="ts_pct"></td><td class="right iz" data-stat="efg_pct"></td><td class="right iz" data-stat="fg3a_per_fga_pct"></td><td class="right iz" data-stat="fta_per_fga_pct"></td><td class="right iz" data-stat="orb_pct"></td><td class="right iz" data-stat="drb_pct"></td><td class="right iz" data-stat="trb_pct"></td><td class="right iz" data-stat="ast_pct"></td><td class="right iz" data-stat="stl_pct"></td><td class="right iz" data-stat="blk_pct"></td><td class="right iz" data-stat="tov_pct"></td><td class="right iz" data-stat="usg_pct"></td><td class="right iz" data-stat="off_rtg"></td><td class="right iz" data-stat="def_rtg"></td><td class="right poptip" data-stat="bpm" data-tip="OBPM: -1.2&lt;br&gt; DBPM: -3.2&lt;br&gt; VORP: 0.0&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-4.5</td></tr>
# <tr data-row="13"><th class="left" csk="Jenkins,John" data-append-csv="jenkijo01" data-stat="player" scope="row"><a href="/players/j/jenkijo01.html">John Jenkins</a></th><td class="center" colspan="16" data-stat="reason">Did Not Play</td></tr>
# </tbody><tfoot><tr data-row="14"><th class="left" data-stat="player" scope="row">Team Totals</th><td class="right" data-stat="mp">240</td><td class="right" data-stat="ts_pct">.661</td><td class="right" data-stat="efg_pct">.625</td><td class="right" data-stat="fg3a_per_fga_pct">.316</td><td class="right" data-stat="fta_per_fga_pct">.395</td><td class="right" data-stat="orb_pct">22.2</td><td class="right" data-stat="drb_pct">73.5</td><td class="right" data-stat="trb_pct">51.8</td><td class="right" data-stat="ast_pct">54.8</td><td class="right" data-stat="stl_pct">8.5</td><td class="right" data-stat="blk_pct">5.1</td><td class="right" data-stat="tov_pct">13.6</td><td class="right" data-stat="usg_pct">100.0</td><td class="right" data-stat="off_rtg">124.7</td><td class="right" data-stat="def_rtg">114.2</td><td class="right iz" data-stat="bpm"></td></tr>
# </tfoot>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div><strong>Inactive: </strong><span><strong>LAC</strong> </span><a href="/players/d/dawsobr01.html">Branden Dawson</a>, <a href="/players/w/wilcocj01.html">C.J. Wilcox</a>   <span><strong>DAL</strong> </span><a href="/players/m/mcgeeja01.html">JaVale McGee</a>, <a href="/players/p/parsoch01.html">Chandler Parsons</a>   </div>
# <div><strong>Officials: </strong><a href="/referees/crawfda99r.html">Dan Crawford</a>, <a href="/referees/tivenjo99r.html">Josh Tiven</a>, <a href="/referees/woodle01r.html">Leon Wood</a></div>
# <div><strong>Attendance: </strong>19,805</div>
# <div><strong>Time of Game: </strong>2:35</div>
# </div>
# <!-- global.nonempty_tables_num: 3, table_count: 3 -->
# <!-- no Local/Partials/NoteBottom.tt2 -->
# <div class="section_wrapper" id="bottom_nav">
# <div class="section_heading"><span class="section_anchor" data-label="Team and League Schedules" data-no-inpage="1" id="inner_nav_bottom_link"></span><h2>Team and League Schedules</h2></div>
# <div class="section_content" id="bottom_nav_container">
# <p><a href="/boxscores/?month=11&amp;day=11&amp;year=2015"><u>Nov 11, 2015 NBA Scores &amp; Boxes</u></a></p>
# <ul class="">
# <li><a href="/teams/LAC/2016_games.html"><u>Los Angeles Clippers Schedule</u></a></li>
# <li><a href="/teams/DAL/2016_games.html"><u>Dallas Mavericks Schedule</u></a></li>
# <li><a href="/leagues/NBA_2016_games.html"><u>2015-16 NBA Schedule &amp; Results</u></a></li>
# </ul></div></div>
# </body></html>': failed to load external entity "<html><body><h1>Los Angeles Clippers at Dallas Mavericks Box Score, November 11, 2015</h1>
# <div class="section_wrappe
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [65], in <cell line: 4>()
#       4 for box_score in box_scores:
#       5     soup = parse_html(box_score)
# ----> 6     line_score = read_line_score(soup)
#       7     teams = list(line_score["team"])
#       9     summaries = []
#
# Input In [62], in read_line_score(soup)
#       1 def read_line_score(soup):
# ----> 2     line_score = pd.read_html(str(soup), attrs={"id": "line_score"})[0]
#       3     cols = list(line_score.columns)
#       4     cols[0] = "team"
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:919, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     916 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918 try:
# --> 919     tables = p.parse_tables()
#     920 except ValueError as caught:
#     921     # if `io` is an io-like object, check if it's seekable
#     922     # and try to rewind it before trying the next parser
#     923     if hasattr(io, "seekable") and io.seekable():
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:239, in _HtmlFrameParser.parse_tables(self)
#     231 def parse_tables(self):
#     232     """
#     233     Parse and return all tables from the DOM.
#     234
#    (...)
#     237     list of parsed (header, body, footer) tuples from tables.
#     238     """
# --> 239     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     240     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:743, in _LxmlFrameParser._build_doc(self)
#     740         r = parse(f, parser=parser)
#     741 else:
#     742     # try to parse the input in the simplest way
# --> 743     r = parse(self.io, parser=parser)
#     744 try:
#     745     r = r.getroot()
#
# KeyboardInterrupt:

# %%
games_df = pd.concat(games, ignore_index=True)

# %%
[g.shape[1] for g in games if g.shape[1] != 150]
# Out:
# [154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154,
#  154]

# %%
games_df.to_csv("nba_games.csv")
